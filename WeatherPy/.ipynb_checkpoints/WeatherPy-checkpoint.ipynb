# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import requests
from pprint import pprint
import json
import os
from citipy import citipy
import random
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import time
CITIES_TOT = 50
SETS_NUM = 2
API_KEY = '726f6729b1b0ce3ac75298331adb8ac7'
URL = "https://api.openweathermap.org/data/2.5/weather?"
parameters = {
    'q' : 'Perth',
    'appid' : API_KEY,
    'units':'metric'
    
}
data_request = requests.get(URL,params =parameters ).json()
data = pprint(data_request)
data
# Out:
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -31.93, 'lon': 115.83},
#  'dt': 1602434173,
#  'id': 2063523,
#  'main': {'feels_like': 11.24,
#           'humidity': 82,
#           'pressure': 1018,
#           'temp': 14.11,
#           'temp_max': 14.44,
#           'temp_min': 13.89},
#  'name': 'Perth',
#  'sys': {'country': 'AU',
#          'id': 9586,
#          'sunrise': 1602452421,
#          'sunset': 1602498338,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 190, 'speed': 4.6}}

# %%
random.seed(6)
ran_lat= [random.uniform(-90,90) for _ in range(CITIES_TOT)]
ran_long = [random.uniform(-180,180) for _ in range(CITIES_TOT)]
dd = list(zip(ran_lat,ran_long))
dd
# Out:
# [(52.80121507709933, 50.79506989241338),
#  (57.95172761755083, 130.97914806108912),
#  (-2.6937669724298416, 144.37845650621716),
#  (-42.90813306996157, -141.362762340362),
#  (-89.91869132068722, 105.73474724547339),
#  (29.307341319078176, -131.28831206929488),
#  (-5.35423372839989, -137.26318619294682),
#  (46.751514317620746, -36.48950835607232),
#  (-22.831133026708514, -4.037571575105346),
#  (48.625170468838235, -154.89101065550173),
#  (-40.91434457904527, -80.76126310937839),
#  (54.344786969268654, -116.82417183756132),
#  (41.36846987196287, -131.4272301245007),
#  (-15.478840590245397, -144.42233243869416),
#  (6.894939519949844, -171.44507612628132),
#  (32.76931343196212, -101.682193471674),
#  (-55.26272236246427, -62.17885970129922),
#  (9.65072978969117, -28.849561486097315),
#  (54.922328972815194, 70.00030019242644),
#  (-42.20621020106963, 40.313734459201925),
#  (54.60575573003638, -4.390852730852686),
#  (33.424178778079366, -63.75979105315413),
#  (61.97081846330968, 41.27269360020702),
#  (-29.595236791353422, -110.55973613093192),
#  (-73.23577340554219, -116.15780747313721),
#  (54.05088956497664, -139.32793677171438),
#  (54.86067239260373, 60.93172830310979),
#  (-9.861765459688229, -129.8594300388525),
#  (-73.11953264473087, -99.7750007248794),
#  (-54.510831936191806, -53.43493724133384),
#  (24.285393382265823, 23.025908150915058),
#  (-37.586958873576194, 53.11497314932217),
#  (81.24714067744429, 33.238271636570914),
#  (15.942563433181348, 34.59892949184086),
#  (-53.84262242151236, -110.65177675320835),
#  (27.972718807173138, 148.55349780094383),
#  (-25.131678226542704, 85.35555667989127),
        city = citipy.nearest_city(rows[0],rows[1])
        cities.append(city.city_name)

generate_cities(dd)
final_cities = list(set(cities))
final_cities = [cities[i:i+SETS_NUM] for i in range(0, len(cities), SETS_NUM)]

# %% [markdown]
# ## Generate Cities List

# %%
json_data = []
print("""Beginning Data Retrieval     
---------------------------------------""")
def get_weather_data(cities,set_num):

    for enum,city in enumerate(cities,start=1):  
        parameters = {
            'q' : city,
            'appid' : API_KEY,
            'units':'metric'

        }
        try:
            
            data_request = requests.get(URL,params =parameters ).json()
            print(f"Processing Record {enum} of Set {set_num} | {data_request['name']}")
            
            
        except:
            print("City not found. Skipping...")
        finally:
            json_data.append(data_request)
#             time.sleep(1)

for n in range(len(final_cities)):
            get_weather_data(final_cities[n],n+1)
            time.sleep(1)
 
print("""-----------------------------
Data Retrieval Complete      
-----------------------------""")
# Out:
# Beginning Data Retrieval
# ---------------------------------------
# Processing Record 1 of Set 1 | Utevka
# City not found. Skipping...
# Processing Record 3 of Set 1 | Wewak
# Processing Record 4 of Set 1 | Rikitea
# Processing Record 5 of Set 1 | Albany
# Processing Record 6 of Set 1 | Pacific Grove
# Processing Record 7 of Set 1 | Atuona
# Processing Record 8 of Set 1 | Ribeira Grande
# Processing Record 9 of Set 1 | Jamestown
# Processing Record 10 of Set 1 | Saint Paul Harbor
# Processing Record 11 of Set 1 | Ancud
# Processing Record 12 of Set 1 | Valleyview
# Processing Record 13 of Set 1 | Eureka
# Processing Record 14 of Set 1 | Tautira
# Processing Record 15 of Set 1 | Kapaa
# Processing Record 16 of Set 1 | Lamesa
# Processing Record 17 of Set 1 | Ushuaia
# Processing Record 18 of Set 1 | São Filipe
# Processing Record 19 of Set 1 | Būlaevo
# Processing Record 20 of Set 1 | Margate
# Processing Record 21 of Set 1 | Whithorn
# Processing Record 22 of Set 1 | Saint George
# Processing Record 23 of Set 1 | Ust'-Shonosha
# Processing Record 24 of Set 1 | Rikitea
# Processing Record 25 of Set 1 | Punta Arenas
# Processing Record 26 of Set 1 | Sitka
# Processing Record 27 of Set 1 | Timiryazevskiy
# Processing Record 28 of Set 1 | Atuona
# Processing Record 29 of Set 1 | Punta Arenas
# Processing Record 30 of Set 1 | Ushuaia
# Processing Record 31 of Set 1 | Jalu
# City not found. Skipping...
# Processing Record 33 of Set 1 | Vardø
# City not found. Skipping...
# Processing Record 35 of Set 1 | Castro
# Processing Record 36 of Set 1 | Katsuura
# Processing Record 37 of Set 1 | Bengkulu
# Processing Record 38 of Set 1 | Tasiilaq
# Processing Record 39 of Set 1 | Tasiilaq
# Processing Record 40 of Set 1 | Isiro
# Processing Record 41 of Set 1 | Pacific Grove
# Processing Record 42 of Set 1 | Damāvand
# Processing Record 43 of Set 1 | Okha
# Processing Record 44 of Set 1 | Upernavik
# Processing Record 45 of Set 1 | Hermanus
# City not found. Skipping...
# Processing Record 47 of Set 1 | Airai
# Processing Record 48 of Set 1 | Cidreira
# Processing Record 49 of Set 1 | Bathsheba
# Processing Record 50 of Set 1 | Busselton
# Processing Record 46 of Set 4 | Vaini
# Processing Record 47 of Set 4 | Barrow
# Processing Record 48 of Set 4 | Prien
# City not found. Skipping...
# Processing Record 50 of Set 4 | Kapaa
# Processing Record 1 of Set 5 | Puerto Ayora
# Processing Record 2 of Set 5 | Ushuaia
# Processing Record 3 of Set 5 | Nikolskoye
# Processing Record 4 of Set 5 | Albany
# Processing Record 5 of Set 5 | Makakilo City
# Processing Record 6 of Set 5 | Assaré
# Processing Record 7 of Set 5 | Prainha
# Processing Record 8 of Set 5 | Rikitea
# Processing Record 9 of Set 5 | Ushuaia
# City not found. Skipping...
# Processing Record 11 of Set 5 | Hobart
# City not found. Skipping...
# Processing Record 13 of Set 5 | Busselton
# Processing Record 14 of Set 5 | Rikitea
# Processing Record 15 of Set 5 | East London
# Processing Record 16 of Set 5 | Hilo
# Processing Record 17 of Set 5 | Mahanoro
# Processing Record 18 of Set 5 | Port Alfred
# Processing Record 19 of Set 5 | Christchurch
# City not found. Skipping...
# Processing Record 21 of Set 5 | Chokurdakh
# Processing Record 22 of Set 5 | San Cristobal
# Processing Record 23 of Set 5 | East London
# Processing Record 24 of Set 5 | Lebu
# Processing Record 25 of Set 5 | Mataura
# Processing Record 26 of Set 5 | Butaritari
# Processing Record 27 of Set 5 | Bethel
# Processing Record 28 of Set 5 | Bathsheba
# Processing Record 29 of Set 5 | Ushuaia
# Processing Record 30 of Set 5 | Rikitea
# Processing Record 31 of Set 5 | Yulara
# Processing Record 32 of Set 5 | Bengkulu
# Processing Record 33 of Set 5 | Santa Maria do Suaçuí
# Processing Record 34 of Set 5 | Longyearbyen
# Processing Record 35 of Set 5 | Plaridel
# Processing Record 36 of Set 5 | Kapaa
# Processing Record 37 of Set 5 | Bereket
# Processing Record 38 of Set 5 | Itoman
# Processing Record 39 of Set 5 | Stupino
# Processing Record 40 of Set 5 | Henties Bay
# Processing Record 41 of Set 5 | Laplace
# Processing Record 42 of Set 5 | Tuktoyaktuk
# Processing Record 43 of Set 5 | Rikitea
# Processing Record 44 of Set 5 | Codrington
# Processing Record 45 of Set 5 | Acarí
# Processing Record 46 of Set 5 | Albany
# Processing Record 47 of Set 5 | Punta Arenas
# Processing Record 48 of Set 5 | Port Hardy
# Processing Record 49 of Set 5 | Albany
# Processing Record 50 of Set 5 | Camacha
# Processing Record 1 of Set 6 | Rikitea
# Processing Record 2 of Set 6 | Carnarvon
# Processing Record 3 of Set 6 | Mataura
# Processing Record 4 of Set 6 | St. George's
# Processing Record 5 of Set 6 | Lagoa
# Processing Record 6 of Set 6 | Cape Town
# Processing Record 7 of Set 6 | Ocós
# Processing Record 8 of Set 6 | Chokurdakh
# Processing Record 9 of Set 6 | Port Alfred
# City not found. Skipping...
# Processing Record 11 of Set 6 | Badamdar
# Processing Record 12 of Set 6 | Tasiilaq
# Processing Record 13 of Set 6 | Bredasdorp
# Processing Record 14 of Set 6 | Eilat
# Processing Record 15 of Set 6 | Punta Arenas
# Processing Record 16 of Set 6 | New Norfolk
# Processing Record 36 of Set 10 | Kapaa
# Processing Record 37 of Set 10 | Narsaq
# Processing Record 38 of Set 10 | Hithadhoo
# Processing Record 39 of Set 10 | Bārmer
# City not found. Skipping...
# Processing Record 41 of Set 10 | Busselton
# Processing Record 42 of Set 10 | Mahébourg
# Processing Record 43 of Set 10 | Chokurdakh
# Processing Record 44 of Set 10 | Lebu
# Processing Record 45 of Set 10 | Cairns
# Processing Record 46 of Set 10 | Mount Isa
# Processing Record 47 of Set 10 | Saskylakh
# Processing Record 48 of Set 10 | Pochutla
# City not found. Skipping...
# Processing Record 50 of Set 10 | New Norfolk
# Processing Record 1 of Set 11 | Esperance
# Processing Record 2 of Set 11 | Ocampo
# Processing Record 3 of Set 11 | Avarua
# Processing Record 4 of Set 11 | Waddān
# Processing Record 5 of Set 11 | Atuona
# Processing Record 6 of Set 11 | Hermanus
# Processing Record 7 of Set 11 | Rikitea
# Processing Record 8 of Set 11 | Atuona
# Processing Record 9 of Set 11 | Airai
# Processing Record 10 of Set 11 | East London
# Processing Record 11 of Set 11 | Mataura
# Processing Record 12 of Set 11 | Bredasdorp
# Processing Record 13 of Set 11 | Ancud
# Processing Record 14 of Set 11 | Jamestown
# Processing Record 15 of Set 11 | Bengkulu
# Processing Record 16 of Set 11 | Airai
# Processing Record 17 of Set 11 | Lavrentiya
# Processing Record 18 of Set 11 | Kapaa
# City not found. Skipping...
# Processing Record 20 of Set 11 | Rikitea
# Processing Record 21 of Set 11 | Palu
# Processing Record 22 of Set 11 | Basqal
# Processing Record 23 of Set 11 | Båtsfjord
# City not found. Skipping...
# Processing Record 25 of Set 11 | Ushuaia
# Processing Record 26 of Set 11 | New Norfolk
# Processing Record 27 of Set 11 | Butaritari
# Processing Record 28 of Set 11 | Clyde River
# Processing Record 29 of Set 11 | Punta Arenas
# Processing Record 30 of Set 11 | Lagoa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
pprint(json_data)
# Out:
# [{'base': 'stations',
#   'clouds': {'all': 85},
#   'cod': 200,
#   'coord': {'lat': 52.9, 'lon': 50.95},
#   'dt': 1602434453,
#   'id': 477744,
#   'main': {'feels_like': 3.91,
#            'grnd_level': 1027,
#            'humidity': 49,
#            'pressure': 1033,
#            'sea_level': 1033,
#            'temp': 8.62,
#            'temp_max': 8.62,
#            'temp_min': 8.62},
#   'name': 'Utevka',
#   'sys': {'country': 'RU', 'sunrise': 1602384914, 'sunset': 1602424213},
#   'timezone': 14400,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 174, 'speed': 3.59}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 97},
#   'cod': 200,
#   'coord': {'lat': -3.55, 'lon': 143.63},
#   'dt': 1602434218,
#   'id': 2083537,
#   'main': {'feels_like': 29.42,
#            'grnd_level': 1003,
#            'humidity': 84,
#            'pressure': 1008,
#            'sea_level': 1008,
#            'temp': 26.3,
#            'temp_max': 26.3,
#            'temp_min': 26.3},
#   'name': 'Wewak',
#   'rain': {'1h': 0.67},
#   'sys': {'country': 'PG', 'sunrise': 1602446796, 'sunset': 1602490621},
#   'timezone': 36000,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 107, 'speed': 3.34}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1602434454,
#   'id': 4030556,
#   'main': {'feels_like': 22.19,
#            'grnd_level': 1020,
#            'humidity': 79,
#            'pressure': 1023,
#            'sea_level': 1023,
#            'temp': 22.95,
#            'temp_max': 22.95,
#            'temp_min': 22.95},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF', 'sunrise': 1602426601, 'sunset': 1602471751},
#   'timezone': -32400,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 81, 'speed': 5.77}},
#  {'base': 'stations',
#   'clouds': {'all': 53},
#   'cod': 200,
#   'coord': {'lat': 42.6, 'lon': -73.97},
#   'dt': 1602434201,
#   'id': 5106841,
#   'main': {'feels_like': 10.51,
#            'humidity': 49,
#            'pressure': 1021,
#            'temp': 12.49,
#            'temp_max': 13.33,
#            'temp_min': 11.67},
#   'name': 'Albany',
#   'sys': {'country': 'US',
#           'id': 19530,
#           'sunrise': 1602414281,
#           'sunset': 1602454797,
#           'type': 3},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 335, 'gust': 1.79, 'speed': 0.45}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 36.62, 'lon': -121.92},
#   'dt': 1602434454,
#   'id': 5380437,
#   'main': {'feels_like': 13.9,
#            'humidity': 93,
#            'pressure': 1019,
#            'temp': 14.36,
#            'temp_max': 15,
#            'temp_min': 13.89},
#   'name': 'Pacific Grove',
#   'sys': {'country': 'US',
#           'id': 4980,
#           'sunrise': 1602425508,
#           'sunset': 1602466581,
#           'type': 1},
#   'timezone': -25200,
#   'visibility': 1207,
#   'weather': [{'description': 'mist',
#                'icon': '50d',
#                'id': 701,
#                'main': 'Mist'}],
#   'wind': {'deg': 290, 'speed': 2.1}},
#  {'base': 'stations',
#   'clouds': {'all': 27},
#   'cod': 200,
#   'coord': {'lat': -9.8, 'lon': -139.03},
#   'dt': 1602434159,
#   'id': 4020109,
#   'main': {'feels_like': 21.9,
#            'grnd_level': 1012,
#            'humidity': 73,
#            'pressure': 1015,
#            'sea_level': 1015,
#            'temp': 25.61,
#            'temp_max': 25.61,
#            'temp_min': 25.61},
#   'name': 'Atuona',
#   'sys': {'country': 'PF', 'sunrise': 1602428041, 'sunset': 1602472260},
#   'timezone': -34200,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 98, 'speed': 10.85}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 38.52, 'lon': -28.7},
#   'dt': 1602434455,
#   'id': 3372707,
#   'main': {'feels_like': 18.89,
#            'humidity': 94,
#            'pressure': 1031,
#            'temp': 20,
#            'temp_max': 20,
#            'temp_min': 20},
#   'name': 'Ribeira Grande',
#   'sys': {'country': 'PT',
#           'id': 6883,
#           'sunrise': 1602403207,
#           'sunset': 1602444144,
#           'type': 1},
#   'timezone': 0,
#   'visibility': 9000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 120, 'speed': 6.2}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 42.1, 'lon': -79.24},
#   'dt': 1602434187,
#   'id': 5122534,
#   'main': {'feels_like': 12.67,
#            'humidity': 71,
#            'pressure': 1020,
#            'temp': 15.44,
#            'temp_max': 17.22,
#            'temp_min': 14},
#   'name': 'Jamestown',
#   'sys': {'country': 'US',
#           'id': 4588,
#           'sunrise': 1602415520,
#           'sunset': 1602456086,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 90, 'speed': 4.1}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 57.79, 'lon': -152.41},
#   'dt': 1602434456,
#   'id': 5866583,
#   'main': {'feels_like': -4.75,
#            'humidity': 92,
#            'pressure': 997,
#            'temp': -1,
#            'temp_max': -1,
#            'temp_min': -1},
#   'name': 'Saint Paul Harbor',
#   'sys': {'country': 'US',
#           'id': 7668,
#           'sunrise': 1602434213,
#           'sunset': 1602472509,
#           'type': 1},
#   'timezone': -28800,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 280, 'speed': 2.1}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -41.87, 'lon': -73.82},
#   'dt': 1602434166,
#   'id': 3899695,
#   'main': {'feels_like': 10.1,
#            'humidity': 62,
#            'pressure': 1025,
#            'temp': 13.18,
#            'temp_max': 13.33,
#            'temp_min': 13},
#   'name': 'Ancud',
#   'sys': {'country': 'CL',
#           'id': 8512,
#           'sunrise': 1602411056,
#           'sunset': 1602457950,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 190, 'speed': 3.1}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 55.07, 'lon': -117.29},
#   'dt': 1602434456,
#   'id': 6173220,
#   'main': {'feels_like': -1.73,
#            'grnd_level': 922,
#            'humidity': 84,
#            'pressure': 1003,
#            'sea_level': 1003,
#            'temp': 3.25,
#            'temp_max': 3.25,
#            'temp_min': 3.25},
#   'name': 'Valleyview',
#   'sys': {'country': 'CA', 'sunrise': 1602425519, 'sunset': 1602464348},
#   'timezone': -21600,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 301, 'speed': 4.45}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 40.8, 'lon': -124.16},
#   'dt': 1602434440,
#   'id': 5563397,
#   'main': {'feels_like': 11.78,
#            'humidity': 81,
#            'pressure': 1023,
#            'temp': 12.72,
#            'temp_max': 13.33,
#            'temp_min': 12},
#   'name': 'Eureka',
#   'sys': {'country': 'US',
#           'id': 3217,
#           'sunrise': 1602426243,
#           'sunset': 1602466921,
#           'type': 1},
#   'timezone': -25200,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 34, 'speed': 1.23}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -17.73, 'lon': -149.15},
#   'dt': 1602434457,
#   'id': 4033557,
#   'main': {'feels_like': 26.03,
#            'humidity': 73,
#            'pressure': 1015,
#            'temp': 23.94,
#            'temp_max': 24,
#            'temp_min': 23.89},
#   'name': 'Tautira',
#   'sys': {'country': 'PF',
#           'id': 7318,
#           'sunrise': 1602430201,
#           'sunset': 1602474957,
#           'type': 1},
#   'timezone': -36000,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 0, 'speed': 1.5}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 22.08, 'lon': -159.32},
#   'dt': 1602434457,
#   'id': 5848280,
#   'main': {'feels_like': 24.8,
#            'humidity': 88,
#            'pressure': 1017,
#            'temp': 22.89,
#            'temp_max': 25,
#            'temp_min': 21.67},
#   'name': 'Kapaa',
#   'rain': {'1h': 2.03},
#   'sys': {'country': 'US',
#           'id': 7873,
#           'sunrise': 1602433923,
#           'sunset': 1602476116,
#           'type': 1},
#   'timezone': -36000,
#   'visibility': 10000,
#   'weather': [{'description': 'moderate rain',
#                'icon': '10d',
#                'id': 501,
#                'main': 'Rain'}],
#   'wind': {'deg': 360, 'speed': 3.1}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 32.74, 'lon': -101.95},
#   'dt': 1602434457,
#   'id': 5524849,
#   'main': {'feels_like': 23.71,
#            'humidity': 12,
#            'pressure': 1014,
#            'temp': 29,
#            'temp_max': 29,
#            'temp_min': 29},
#   'name': 'Lamesa',
#   'sys': {'country': 'US',
#           'id': 9741,
#           'sunrise': 1602420547,
#           'sunset': 1602461959,
#           'type': 1},
#   'timezone': -18000,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 240, 'speed': 4.1}},
#  {'base': 'stations',
#   'clouds': {'all': 77},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1602433896,
#   'id': 3833367,
#   'main': {'feels_like': 4,
#            'grnd_level': 987,
#            'humidity': 75,
#            'pressure': 993,
#            'sea_level': 993,
#            'temp': 7.55,
#            'temp_max': 7.55,
#            'temp_min': 7.55},
#   'name': 'Ushuaia',
#   'rain': {'1h': 0.22},
#   'sys': {'country': 'AR', 'sunrise': 1602408725, 'sunset': 1602457631},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 282, 'speed': 3.03}},
#  {'base': 'stations',
#   'clouds': {'all': 6},
#   'cod': 200,
#   'coord': {'lat': 14.9, 'lon': -24.5},
#   'dt': 1602434458,
#   'id': 3374210,
#   'main': {'feels_like': 28.85,
#            'grnd_level': 1006,
#            'humidity': 75,
#            'pressure': 1011,
#            'sea_level': 1011,
#            'temp': 26.83,
#            'temp_max': 26.83,
#            'temp_min': 26.83},
#   'name': 'São Filipe',
#   'sys': {'country': 'CV', 'sunrise': 1602401324, 'sunset': 1602444013},
#   'timezone': -3600,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 41, 'speed': 3.84}},
#  {'base': 'stations',
#   'clouds': {'all': 16},
#   'cod': 200,
#   'coord': {'lat': 54.91, 'lon': 70.44},
#   'dt': 1602434458,
#   'id': 1525014,
#   'main': {'feels_like': 2.91,
#            'grnd_level': 1009,
#            'humidity': 91,
#            'pressure': 1026,
#            'sea_level': 1026,
#            'temp': 6.38,
#            'temp_max': 6.38,
#            'temp_min': 6.38},
#   'name': 'Būlaevo',
#   'sys': {'country': 'KZ', 'sunrise': 1602380389, 'sunset': 1602419384},
#   'timezone': 21600,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 292, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 89},
#   'cod': 200,
#   'coord': {'lat': 51.38, 'lon': 1.39},
#   'dt': 1602434458,
#   'id': 2643044,
#   'main': {'feels_like': 12.87,
#            'humidity': 69,
#            'pressure': 1020,
#            'temp': 13.89,
#            'temp_max': 15.56,
#            'temp_min': 12.22},
#   'name': 'Margate',
#   'sys': {'country': 'GB',
#           'id': 2001377,
#           'sunrise': 1602396711,
#           'sunset': 1602436200,
#           'type': 3},
#   'timezone': 3600,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 136, 'gust': 1.79, 'speed': 0.89}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 18.26, 'lon': -78.04},
#   'dt': 1602434459,
#   'id': 3491102,
#   'main': {'feels_like': 32.65,
#            'humidity': 70,
#            'pressure': 1013,
#            'temp': 30.78,
#            'temp_max': 31,
#            'temp_min': 30.56},
#   'name': 'Whithorn',
#   'sys': {'country': 'JM',
#           'id': 7107,
#           'sunrise': 1602414283,
#           'sunset': 1602456748,
#           'type': 1},
#   'timezone': -18000,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 40, 'speed': 6.2}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 37.1, 'lon': -113.58},
#   'dt': 1602434459,
#   'id': 5546220,
#   'main': {'feels_like': 17.2,
#            'humidity': 27,
#            'pressure': 1016,
#            'temp': 20.52,
#            'temp_max': 22.78,
#            'temp_min': 18},
#   'name': 'Saint George',
#   'sys': {'country': 'US',
#           'id': 5832,
#           'sunrise': 1602423527,
#           'sunset': 1602464560,
#           'type': 1},
#   'timezone': -21600,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 180, 'speed': 2.1}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 61.15, 'lon': 41.34},
#   'dt': 1602434459,
#   'id': 477958,
#   'main': {'feels_like': 9.53,
#            'grnd_level': 1008,
#            'humidity': 96,
#            'pressure': 1021,
#            'sea_level': 1021,
#            'temp': 10.59,
#            'temp_max': 10.59,
#            'temp_min': 10.59},
#   'name': "Ust'-Shonosha",
#   'sys': {'country': 'RU', 'sunrise': 1602388001, 'sunset': 1602425737},
#   'timezone': 10800,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 127, 'speed': 1.57}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1602434454,
#   'id': 4030556,
#   'main': {'feels_like': 22.19,
#            'grnd_level': 1020,
#            'humidity': 79,
#            'pressure': 1023,
#            'sea_level': 1023,
#            'temp': 22.95,
#            'temp_max': 22.95,
#            'temp_min': 22.95},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF', 'sunrise': 1602426601, 'sunset': 1602471751},
#   'timezone': -32400,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 81, 'speed': 5.77}},
#  {'base': 'stations',
#   'clouds': {'all': 27},
#   'cod': 200,
#   'coord': {'lat': -53.15, 'lon': -70.92},
#   'dt': 1602434214,
#   'id': 3874787,
#   'main': {'feels_like': -2.12,
#            'humidity': 58,
#            'pressure': 996,
#            'temp': 11.83,
#            'temp_max': 12,
#            'temp_min': 11.67},
#   'name': 'Punta Arenas',
#   'sys': {'country': 'CL',
#           'id': 8487,
#           'sunrise': 1602409516,
#           'sunset': 1602458098,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 280, 'speed': 18}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 57.05, 'lon': -135.33},
#   'dt': 1602434183,
#   'id': 5557293,
#   'main': {'feels_like': 3.64,
#            'humidity': 81,
#            'pressure': 1003,
#            'temp': 8,
#            'temp_max': 8,
#            'temp_min': 8},
#   'name': 'Sitka',
#   'rain': {'1h': 0.25},
#   'sys': {'country': 'US',
#           'id': 7795,
#           'sunrise': 1602430035,
#           'sunset': 1602468490,
#           'type': 1},
#   'timezone': -28800,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 110, 'speed': 4.6}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 56.49, 'lon': 84.88},
#   'dt': 1602434460,
#   'id': 1489597,
#   'main': {'feels_like': -2.51,
#            'humidity': 92,
#            'pressure': 1012,
#            'temp': 0.89,
#            'temp_max': 1.11,
#            'temp_min': 0.56},
#   'name': 'Timiryazevskiy',
#   'rain': {'1h': 0.22},
#   'sys': {'country': 'RU',
#           'id': 2011808,
#           'sunrise': 1602377055,
#           'sunset': 1602415788,
#           'type': 3},
#   'timezone': 25200,
#   'visibility': 4299,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 158, 'speed': 1.96}},
#  {'base': 'stations',
#   'clouds': {'all': 27},
#   'cod': 200,
#   'coord': {'lat': -9.8, 'lon': -139.03},
#   'dt': 1602434159,
#   'id': 4020109,
#   'main': {'feels_like': 21.9,
#            'grnd_level': 1012,
#            'humidity': 73,
#            'pressure': 1015,
#            'sea_level': 1015,
#            'temp': 25.61,
#            'temp_max': 25.61,
#            'temp_min': 25.61},
#   'name': 'Atuona',
#   'sys': {'country': 'PF', 'sunrise': 1602428041, 'sunset': 1602472260},
#   'timezone': -34200,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 98, 'speed': 10.85}},
#  {'base': 'stations',
#   'clouds': {'all': 27},
#   'cod': 200,
#   'coord': {'lat': -53.15, 'lon': -70.92},
#   'dt': 1602434214,
#   'id': 3874787,
#   'main': {'feels_like': -2.12,
#            'humidity': 58,
#            'pressure': 996,
#            'temp': 11.83,
#            'temp_max': 12,
#            'temp_min': 11.67},
#   'name': 'Punta Arenas',
#   'sys': {'country': 'CL',
#           'id': 8487,
#           'sunrise': 1602409516,
#           'sunset': 1602458098,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 280, 'speed': 18}},
#  {'base': 'stations',
#   'clouds': {'all': 77},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1602433896,
#   'id': 3833367,
#   'main': {'feels_like': 4,
#            'grnd_level': 987,
#            'humidity': 75,
#            'pressure': 993,
#            'sea_level': 993,
#            'temp': 7.55,
#            'temp_max': 7.55,
#            'temp_min': 7.55},
#   'name': 'Ushuaia',
#   'rain': {'1h': 0.22},
#   'sys': {'country': 'AR', 'sunrise': 1602408725, 'sunset': 1602457631},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 282, 'speed': 3.03}},
#  {'base': 'stations',
#   'clouds': {'all': 79},
#   'cod': 200,
#   'coord': {'lat': 29.03, 'lon': 21.55},
#   'dt': 1602434461,
#   'id': 86049,
#   'main': {'feels_like': 22.64,
#            'grnd_level': 1010,
#            'humidity': 33,
#            'pressure': 1015,
#            'sea_level': 1015,
#            'temp': 25.72,
#            'temp_max': 25.72,
#            'temp_min': 25.72},
#   'name': 'Jalu',
#   'sys': {'country': 'LY', 'sunrise': 1602390749, 'sunset': 1602432488},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 21, 'speed': 3.82}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 70.37, 'lon': 31.11},
#   'dt': 1602434398,
#   'id': 777019,
#   'main': {'feels_like': 0.13,
#            'humidity': 87,
#            'pressure': 1016,
#            'temp': 7,
#            'temp_max': 7,
#            'temp_min': 7},
#   'name': 'Vardø',
#   'sys': {'country': 'NO',
#           'id': 1666,
#           'sunrise': 1602392039,
#           'sunset': 1602426609,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 40, 'speed': 8.2}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 2},
#   'cod': 200,
#   'coord': {'lat': -24.79, 'lon': -50.01},
#   'dt': 1602434462,
#   'id': 3466704,
#   'main': {'feels_like': 21.91,
#            'grnd_level': 906,
#            'humidity': 48,
#            'pressure': 1016,
#            'sea_level': 1016,
#            'temp': 22.77,
#            'temp_max': 22.77,
#            'temp_min': 22.77},
#   'name': 'Castro',
#   'sys': {'country': 'BR', 'sunrise': 1602406160, 'sunset': 1602451419},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 83, 'speed': 1.77}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 35.13, 'lon': 140.3},
#   'dt': 1602434451,
#   'id': 2112309,
#   'main': {'feels_like': 18.41,
#            'humidity': 88,
#            'pressure': 1011,
#            'temp': 19.74,
#            'temp_max': 20,
#            'temp_min': 19.44},
#   'name': 'Katsuura',
#   'sys': {'country': 'JP',
#           'id': 8074,
#           'sunrise': 1602448923,
#           'sunset': 1602490092,
#           'type': 1},
#   'timezone': 32400,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 350, 'speed': 5.7}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -3.8, 'lon': 102.27},
#   'dt': 1602434440,
#   'id': 1649150,
#   'main': {'feels_like': 28.42,
#            'grnd_level': 1007,
#            'humidity': 88,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 24.61,
#            'temp_max': 24.61,
#            'temp_min': 24.61},
#   'name': 'Bengkulu',
#   'sys': {'country': 'ID', 'sunrise': 1602370334, 'sunset': 1602414163},
#   'timezone': 25200,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 334, 'speed': 1.65}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 65.61, 'lon': -37.64},
#   'dt': 1602434206,
#   'id': 3424607,
#   'main': {'feels_like': -5.81,
#            'humidity': 96,
#            'pressure': 1013,
#            'temp': 3,
#            'temp_max': 3,
#            'temp_min': 3},
#   'name': 'Tasiilaq',
#   'sys': {'country': 'GL',
#           'id': 81,
#           'sunrise': 1602407617,
#           'sunset': 1602444025,
#           'type': 1},
#   'timezone': -7200,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 100, 'speed': 10.3}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 65.61, 'lon': -37.64},
#   'dt': 1602434206,
#   'id': 3424607,
#   'main': {'feels_like': -5.81,
#            'humidity': 96,
#            'pressure': 1013,
#            'temp': 3,
#            'temp_max': 3,
#            'temp_min': 3},
#   'name': 'Tasiilaq',
#   'sys': {'country': 'GL',
#           'id': 81,
#           'sunrise': 1602407617,
#           'sunset': 1602444025,
#           'type': 1},
#   'timezone': -7200,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 100, 'speed': 10.3}},
#  {'base': 'stations',
#   'clouds': {'all': 63},
#   'cod': 200,
#   'coord': {'lat': 2.77, 'lon': 27.62},
#   'dt': 1602434464,
#   'id': 215771,
#   'main': {'feels_like': 25.15,
#            'grnd_level': 927,
#            'humidity': 84,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 22.38,
#            'temp_max': 22.38,
#            'temp_min': 22.38},
#   'name': 'Isiro',
#   'sys': {'country': 'CD', 'sunrise': 1602388444, 'sunset': 1602431879},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 312, 'speed': 1.02}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 36.62, 'lon': -121.92},
#   'dt': 1602434454,
#   'id': 5380437,
#   'main': {'feels_like': 13.9,
#            'humidity': 93,
#            'pressure': 1019,
#            'temp': 14.36,
#            'temp_max': 15,
#            'temp_min': 13.89},
#   'name': 'Pacific Grove',
#   'sys': {'country': 'US',
#           'id': 4980,
#           'sunrise': 1602425508,
#           'sunset': 1602466581,
#           'type': 1},
#   'timezone': -25200,
#   'visibility': 1207,
#   'weather': [{'description': 'mist',
#                'icon': '50d',
#                'id': 701,
#                'main': 'Mist'}],
#   'wind': {'deg': 290, 'speed': 2.1}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 35.72, 'lon': 52.06},
#   'dt': 1602434464,
#   'id': 138042,
#   'main': {'feels_like': 14.48,
#            'humidity': 31,
#            'pressure': 1025,
#            'temp': 17.86,
#            'temp_max': 18,
#            'temp_min': 17.78},
#   'name': 'Damāvand',
#   'sys': {'country': 'IR',
#           'id': 7464,
#           'sunrise': 1602383689,
#           'sunset': 1602424905,
#           'type': 1},
#   'timezone': 12600,
#   'visibility': 5000,
#   'weather': [{'description': 'haze',
#                'icon': '50n',
#                'id': 721,
#                'main': 'Haze'}],
#   'wind': {'deg': 220, 'speed': 2.1}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 53.57, 'lon': 142.95},
#   'dt': 1602434245,
#   'id': 2122614,
#   'main': {'feels_like': 3.24,
#            'grnd_level': 1009,
#            'humidity': 81,
#            'pressure': 1011,
#            'sea_level': 1011,
#            'temp': 8.88,
#            'temp_max': 8.88,
#            'temp_min': 8.88},
#   'name': 'Okha',
#   'sys': {'country': 'RU', 'sunrise': 1602449367, 'sunset': 1602488377},
#   'timezone': 39600,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 172, 'speed': 6.69}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 72.79, 'lon': -56.15},
#   'dt': 1602434401,
#   'id': 3418910,
#   'main': {'feels_like': -0.77,
#            'grnd_level': 1000,
#            'humidity': 75,
#            'pressure': 1000,
#            'sea_level': 1000,
#            'temp': 3.07,
#            'temp_max': 3.07,
#            'temp_min': 3.07},
#   'name': 'Upernavik',
#   'sys': {'country': 'GL', 'sunrise': 1602413746, 'sunset': 1602446779},
#   'timezone': -7200,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 138, 'speed': 2.46}},
#  {'base': 'stations',
#   'clouds': {'all': 99},
#   'cod': 200,
#   'coord': {'lat': -34.42, 'lon': 19.23},
#   'dt': 1602434465,
#   'id': 3366880,
#   'main': {'feels_like': 12.97,
#            'humidity': 61,
#            'pressure': 1022,
#            'temp': 16.11,
#            'temp_max': 16.11,
#            'temp_min': 16.11},
#   'name': 'Hermanus',
#   'sys': {'country': 'ZA',
#           'id': 2006131,
#           'sunrise': 1602389143,
#           'sunset': 1602435206,
#           'type': 3},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 111, 'gust': 7.15, 'speed': 4.02}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 69},
#   'cod': 200,
#   'coord': {'lat': -8.93, 'lon': 125.41},
#   'dt': 1602434466,
#   'id': 1651810,
#   'main': {'feels_like': 15.1,
#            'grnd_level': 853,
#            'humidity': 88,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 15.17,
#            'temp_max': 15.17,
#            'temp_min': 15.17},
#   'name': 'Airai',
#   'sys': {'country': 'TL', 'sunrise': 1602450995, 'sunset': 1602495166},
#   'timezone': 32400,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 98, 'speed': 1.52}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -30.18, 'lon': -50.21},
#   'dt': 1602434181,
#   'id': 3466165,
#   'main': {'feels_like': 15.21,
#            'grnd_level': 1016,
#            'humidity': 66,
#            'pressure': 1017,
#            'sea_level': 1017,
#            'temp': 19.66,
#            'temp_max': 19.66,
#            'temp_min': 19.66},
#   'name': 'Cidreira',
#   'sys': {'country': 'BR', 'sunrise': 1602405987, 'sunset': 1602451688},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 51, 'speed': 7.75}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 13.22, 'lon': -59.52},
#   'dt': 1602434219,
#   'id': 3374083,
#   'main': {'feels_like': 31.43,
#            'humidity': 70,
#            'pressure': 1013,
#            'temp': 30,
#            'temp_max': 30,
#            'temp_min': 30},
#   'name': 'Bathsheba',
#   'sys': {'country': 'BB',
#           'id': 8772,
#           'sunrise': 1602409676,
#           'sunset': 1602452467,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 140, 'speed': 6.2}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.65, 'lon': 115.33},
#   'dt': 1602434129,
#   'id': 2075265,
#   'main': {'feels_like': 6.07,
#            'humidity': 72,
#            'pressure': 1013,
#            'temp': 9.29,
#            'temp_max': 10.56,
#            'temp_min': 7.78},
#   'name': 'Busselton',
#   'sys': {'country': 'AU',
#           'id': 2011706,
#           'sunrise': 1602452459,
#           'sunset': 1602498540,
#           'type': 3},
#   'timezone': 28800,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 141, 'speed': 2.85}},
#  {'base': 'stations',
#   'clouds': {'all': 62},
#   'cod': 200,
#   'coord': {'lat': 69.22, 'lon': -51.1},
#   'dt': 1602434401,
#   'id': 3423146,
#   'main': {'feels_like': -2.55,
#            'humidity': 80,
#            'pressure': 1002,
#            'temp': 4,
#            'temp_max': 4,
#            'temp_min': 4},
#   'name': 'Ilulissat',
#   'sys': {'country': 'GL',
#           'id': 165,
#           'sunrise': 1602411552,
#           'sunset': 1602446550,
#           'type': 1},
#   'timezone': -7200,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 130, 'speed': 6.7}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -2.02, 'lon': 147.27},
#   'dt': 1602434469,
#   'id': 2092164,
#   'main': {'feels_like': 30.07,
#            'grnd_level': 1007,
#            'humidity': 82,
#            'pressure': 1007,
#            'sea_level': 1007,
#            'temp': 27.39,
#            'temp_max': 27.39,
#            'temp_min': 27.39},
#   'name': 'Lorengau',
#   'rain': {'1h': 0.19},
#   'sys': {'country': 'PG', 'sunrise': 1602445971, 'sunset': 1602489699},
#   'timezone': 36000,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 106, 'speed': 4.52}},
#  {'base': 'stations',
#   'clouds': {'all': 77},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1602433896,
#   'id': 3833367,
#   'main': {'feels_like': 4,
#            'grnd_level': 987,
#            'humidity': 75,
#            'pressure': 993,
#            'sea_level': 993,
#            'temp': 7.55,
#            'temp_max': 7.55,
#            'temp_min': 7.55},
#   'name': 'Ushuaia',
#   'rain': {'1h': 0.22},
#   'sys': {'country': 'AR', 'sunrise': 1602408725, 'sunset': 1602457631},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 282, 'speed': 3.03}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 29.97, 'lon': 32.53},
#   'dt': 1602434405,
#   'id': 359796,
#   'main': {'feels_like': 23.2,
#            'grnd_level': 1013,
#            'humidity': 64,
#            'pressure': 1014,
#            'sea_level': 1014,
#            'temp': 24.3,
#            'temp_max': 24.3,
#            'temp_min': 24.3},
#   'name': 'Suez',
#   'sys': {'country': 'EG', 'sunrise': 1602388148, 'sunset': 1602429819},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 9, 'speed': 4.99}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.82, 'lon': -70.75},
#   'dt': 1602434469,
#   'id': 3877739,
#   'main': {'feels_like': 24.91,
#            'humidity': 28,
#            'pressure': 1015,
#            'temp': 26.43,
#            'temp_max': 27.22,
#            'temp_min': 25},
#   'name': 'Paine',
#   'sys': {'country': 'CL',
#           'id': 8506,
#           'sunrise': 1602410747,
#           'sunset': 1602456785,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 230, 'speed': 1}},
#  {'base': 'stations',
#   'clouds': {'all': 50},
#   'cod': 200,
#   'coord': {'lat': -33.59, 'lon': 26.89},
#   'dt': 1602434470,
#   'id': 964432,
#   'main': {'feels_like': 10.7,
#            'grnd_level': 1023,
#            'humidity': 61,
#            'pressure': 1025,
#            'sea_level': 1025,
#            'temp': 13.76,
#            'temp_max': 13.76,
#            'temp_min': 13.76},
#   'name': 'Port Alfred',
#   'sys': {'country': 'ZA', 'sunrise': 1602387346, 'sunset': 1602433328},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 120, 'speed': 3.18}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 5.41, 'lon': 100.34},
#   'dt': 1602434131,
#   'id': 1735106,
#   'main': {'feels_like': 31.58,
#            'humidity': 88,
#            'pressure': 1007,
#            'temp': 26.83,
#            'temp_max': 27,
#            'temp_min': 26.67},
#   'name': 'George Town',
#   'sys': {'country': 'MY',
#           'id': 9429,
#           'sunrise': 1602457465,
#           'sunset': 1602500728,
#           'type': 1},
#   'timezone': 28800,
#   'visibility': 8000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 70, 'speed': 2.1}},
#  {'base': 'stations',
#   'clouds': {'all': 86},
#   'cod': 200,
#   'coord': {'lat': -46.19, 'lon': 168.86},
#   'dt': 1602434470,
#   'id': 6201424,
#   'main': {'feels_like': 8.92,
#            'humidity': 90,
#            'pressure': 1015,
#            'temp': 11.67,
#            'temp_max': 11.67,
#            'temp_min': 11.67},
#   'name': 'Mataura',
#   'sys': {'country': 'NZ',
#           'id': 2008959,
#           'sunrise': 1602438896,
#           'sunset': 1602486413,
#           'type': 3},
#   'timezone': 46800,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 238, 'gust': 7.15, 'speed': 4.02}},
#  {'base': 'stations',
#   'clouds': {'all': 13},
#   'cod': 200,
#   'coord': {'lat': -42.78, 'lon': 147.06},
#   'dt': 1602434194,
#   'id': 2155415,
#   'main': {'feels_like': 3.16,
#            'humidity': 86,
#            'pressure': 1020,
#            'temp': 5.49,
#            'temp_max': 6.67,
#            'temp_min': 5},
#   'name': 'New Norfolk',
#   'sys': {'country': 'AU',
#           'id': 2031307,
#           'sunrise': 1602444350,
#           'sunset': 1602491421,
#           'type': 3},
#   'timezone': 39600,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 293, 'speed': 1.27}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 65.28, 'lon': -126.83},
#   'dt': 1602434433,
#   'id': 6089245,
#   'main': {'feels_like': -2.77,
#            'humidity': 96,
#            'pressure': 1003,
#            'temp': 0,
#            'temp_max': 0,
#            'temp_min': 0},
#   'name': 'Norman Wells',
#   'sys': {'country': 'CA',
#           'id': 951,
#           'sunrise': 1602429016,
#           'sunset': 1602465430,
#           'type': 1},
#   'timezone': -21600,
#   'visibility': 6437,
#   'weather': [{'description': 'light snow',
#                'icon': '13d',
#                'id': 600,
#                'main': 'Snow'}],
#   'wind': {'deg': 0, 'speed': 1}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 35.51, 'lon': 27.21},
#   'dt': 1602434471,
#   'id': 260895,
#   'main': {'feels_like': 22.75,
#            'humidity': 64,
#            'pressure': 1015,
#            'temp': 23,
#            'temp_max': 23,
#            'temp_min': 23},
#   'name': 'Karpathos',
#   'rain': {'1h': 0.27},
#   'sys': {'country': 'GR',
#           'id': 6620,
#           'sunrise': 1602389647,
#           'sunset': 1602430873,
#           'type': 1},
#   'timezone': 10800,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 320, 'speed': 3.1}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 11, 'lon': 122.67},
#   'dt': 1602434472,
#   'id': 1714733,
#   'main': {'feels_like': 28.16,
#            'grnd_level': 1004,
#            'humidity': 90,
#            'pressure': 1007,
#            'sea_level': 1007,
#            'temp': 24.02,
#            'temp_max': 24.02,
#            'temp_min': 24.02},
#   'name': 'Dingle',
#   'sys': {'country': 'PH', 'sunrise': 1602452282, 'sunset': 1602495194},
#   'timezone': 28800,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 339, 'speed': 1.01}},
#  {'base': 'stations',
#   'clouds': {'all': 77},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1602433896,
#   'id': 3833367,
#   'main': {'feels_like': 4,
#            'grnd_level': 987,
#            'humidity': 75,
#            'pressure': 993,
#            'sea_level': 993,
#            'temp': 7.55,
#            'temp_max': 7.55,
#            'temp_min': 7.55},
#   'name': 'Ushuaia',
#   'rain': {'1h': 0.22},
#   'sys': {'country': 'AR', 'sunrise': 1602408725, 'sunset': 1602457631},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 282, 'speed': 3.03}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 42.1, 'lon': -79.24},
#   'dt': 1602434187,
#   'id': 5122534,
#   'main': {'feels_like': 12.67,
#            'humidity': 71,
#            'pressure': 1020,
#            'temp': 15.44,
#            'temp_max': 17.22,
#            'temp_min': 14},
#   'name': 'Jamestown',
#   'sys': {'country': 'US',
#           'id': 4588,
#           'sunrise': 1602415520,
#           'sunset': 1602456086,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 90, 'speed': 4.1}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 69.38, 'lon': 178.42},
#   'dt': 1602434472,
#   'id': 2123814,
#   'main': {'feels_like': -4.67,
#            'grnd_level': 1020,
#            'humidity': 98,
#            'pressure': 1021,
#            'sea_level': 1021,
#            'temp': -1.27,
#            'temp_max': -1.27,
#            'temp_min': -1.27},
#   'name': 'Leningradskiy',
#   'sys': {'country': 'RU', 'sunrise': 1602442990, 'sunset': 1602477731},
#   'timezone': 43200,
#   'visibility': 943,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 350, 'speed': 1.71}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 22.08, 'lon': -159.32},
#   'dt': 1602434457,
#   'id': 5848280,
#   'main': {'feels_like': 24.8,
#            'humidity': 88,
#            'pressure': 1017,
#            'temp': 22.89,
#            'temp_max': 25,
#            'temp_min': 21.67},
#   'name': 'Kapaa',
#   'rain': {'1h': 2.03},
#   'sys': {'country': 'US',
#           'id': 7873,
#           'sunrise': 1602433923,
#           'sunset': 1602476116,
#           'type': 1},
#   'timezone': -36000,
#   'visibility': 10000,
#   'weather': [{'description': 'moderate rain',
#                'icon': '10d',
#                'id': 501,
#                'main': 'Rain'}],
#   'wind': {'deg': 360, 'speed': 3.1}},
#  {'base': 'stations',
#   'clouds': {'all': 17},
#   'cod': 200,
#   'coord': {'lat': -34.93, 'lon': 138.6},
#   'dt': 1602434473,
#   'id': 2078025,
#   'main': {'feels_like': 12.5,
#            'humidity': 48,
#            'pressure': 1018,
#            'temp': 16.42,
#            'temp_max': 18,
#            'temp_min': 13.89},
#   'name': 'Adelaide',
#   'sys': {'country': 'AU',
#           'id': 9566,
#           'sunrise': 1602446817,
#           'sunset': 1602493015,
#           'type': 1},
#   'timezone': 37800,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 40, 'speed': 4.1}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -23.86, 'lon': 35.38},
#   'dt': 1602434277,
#   'id': 1045114,
#   'main': {'feels_like': 20.6,
#            'humidity': 83,
#            'pressure': 1018,
#            'temp': 20.77,
#            'temp_max': 21,
#            'temp_min': 20.56},
#   'name': 'Inhambane',
#   'sys': {'country': 'MZ',
#           'id': 2200,
#           'sunrise': 1602385716,
#           'sunset': 1602430883,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 150, 'speed': 4.1}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 42.1, 'lon': -79.24},
#   'dt': 1602434187,
#   'id': 5122534,
#   'main': {'feels_like': 12.67,
#            'humidity': 71,
#            'pressure': 1020,
#            'temp': 15.44,
#            'temp_max': 17.22,
#            'temp_min': 14},
#   'name': 'Jamestown',
#   'sys': {'country': 'US',
#           'id': 4588,
#           'sunrise': 1602415520,
#           'sunset': 1602456086,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 90, 'speed': 4.1}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -33.02, 'lon': 27.91},
#   'dt': 1602434022,
#   'id': 1006984,
#   'main': {'feels_like': 12.79,
#            'humidity': 58,
#            'pressure': 1026,
#            'temp': 15,
#            'temp_max': 15,
#            'temp_min': 15},
#   'name': 'East London',
#   'sys': {'country': 'ZA',
#           'id': 1912,
#           'sunrise': 1602387127,
#           'sunset': 1602433057,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 140, 'speed': 2.1}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 53},
#   'cod': 200,
#   'coord': {'lat': 42.6, 'lon': -73.97},
#   'dt': 1602434201,
#   'id': 5106841,
#   'main': {'feels_like': 10.51,
#            'humidity': 49,
#            'pressure': 1021,
#            'temp': 12.49,
#            'temp_max': 13.33,
#            'temp_min': 11.67},
#   'name': 'Albany',
#   'sys': {'country': 'US',
#           'id': 19530,
#           'sunrise': 1602414281,
#           'sunset': 1602454797,
#           'type': 3},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 335, 'gust': 1.79, 'speed': 0.45}},
#  {'base': 'stations',
#   'clouds': {'all': 97},
#   'cod': 200,
#   'coord': {'lat': -13.88, 'lon': 167.55},
#   'dt': 1602434444,
#   'id': 2134814,
#   'main': {'feels_like': 26.18,
#            'grnd_level': 1003,
#            'humidity': 83,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 27.31,
#            'temp_max': 27.31,
#            'temp_min': 27.31},
#   'name': 'Sola',
#   'sys': {'country': 'VU', 'sunrise': 1602440721, 'sunset': 1602485217},
#   'timezone': 39600,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 120, 'speed': 10.06}},
#  {'base': 'stations',
#   'clouds': {'all': 10},
#   'cod': 200,
#   'coord': {'lat': 44.38, 'lon': 4.99},
#   'dt': 1602434475,
#   'id': 2970838,
#   'main': {'feels_like': 2.47,
#            'humidity': 54,
#            'pressure': 1016,
#            'temp': 12.5,
#            'temp_max': 14,
#            'temp_min': 11.11},
#   'name': 'Valréas',
#   'sys': {'country': 'FR',
#           'id': 6516,
#           'sunrise': 1602395410,
#           'sunset': 1602435774,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
# ...
#  {'base': 'stations',
#   'clouds': {'all': 99},
#   'cod': 200,
#   'coord': {'lat': -34.42, 'lon': 19.23},
#   'dt': 1602434465,
#   'id': 3366880,
#   'main': {'feels_like': 12.97,
#            'humidity': 61,
#            'pressure': 1022,
#            'temp': 16.11,
#            'temp_max': 16.11,
#            'temp_min': 16.11},
#   'name': 'Hermanus',
#   'sys': {'country': 'ZA',
#           'id': 2006131,
#           'sunrise': 1602389143,
#           'sunset': 1602435206,
#           'type': 3},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 111, 'gust': 7.15, 'speed': 4.02}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1602434454,
#   'id': 4030556,
#   'main': {'feels_like': 22.19,
#            'grnd_level': 1020,
#            'humidity': 79,
#            'pressure': 1023,
#            'sea_level': 1023,
#            'temp': 22.95,
#            'temp_max': 22.95,
#            'temp_min': 22.95},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF', 'sunrise': 1602426601, 'sunset': 1602471751},
#   'timezone': -32400,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 81, 'speed': 5.77}},
#  {'base': 'stations',
#   'clouds': {'all': 27},
#   'cod': 200,
#   'coord': {'lat': -9.8, 'lon': -139.03},
#   'dt': 1602434159,
#   'id': 4020109,
#   'main': {'feels_like': 21.9,
#            'grnd_level': 1012,
#            'humidity': 73,
#            'pressure': 1015,
#            'sea_level': 1015,
#            'temp': 25.61,
#            'temp_max': 25.61,
#            'temp_min': 25.61},
#   'name': 'Atuona',
#   'sys': {'country': 'PF', 'sunrise': 1602428041, 'sunset': 1602472260},
#   'timezone': -34200,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 98, 'speed': 10.85}},
#  {'base': 'stations',
#   'clouds': {'all': 69},
#   'cod': 200,
#   'coord': {'lat': -8.93, 'lon': 125.41},
#   'dt': 1602434466,
#   'id': 1651810,
#   'main': {'feels_like': 15.1,
#            'grnd_level': 853,
#            'humidity': 88,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 15.17,
#            'temp_max': 15.17,
#            'temp_min': 15.17},
#   'name': 'Airai',
#   'sys': {'country': 'TL', 'sunrise': 1602450995, 'sunset': 1602495166},
#   'timezone': 32400,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 98, 'speed': 1.52}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -33.02, 'lon': 27.91},
#   'dt': 1602434022,
#   'id': 1006984,
#   'main': {'feels_like': 12.79,
#            'humidity': 58,
#            'pressure': 1026,
#            'temp': 15,
#            'temp_max': 15,
#            'temp_min': 15},
#   'name': 'East London',
#   'sys': {'country': 'ZA',
#           'id': 1912,
#           'sunrise': 1602387127,
#           'sunset': 1602433057,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 140, 'speed': 2.1}},
#  {'base': 'stations',
#   'clouds': {'all': 86},
#   'cod': 200,
#   'coord': {'lat': -46.19, 'lon': 168.86},
#   'dt': 1602434470,
#   'id': 6201424,
#   'main': {'feels_like': 8.92,
#            'humidity': 90,
#            'pressure': 1015,
#            'temp': 11.67,
#            'temp_max': 11.67,
#            'temp_min': 11.67},
#   'name': 'Mataura',
#   'sys': {'country': 'NZ',
#           'id': 2008959,
#           'sunrise': 1602438896,
#           'sunset': 1602486413,
#           'type': 3},
#   'timezone': 46800,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 238, 'gust': 7.15, 'speed': 4.02}},
#  {'base': 'stations',
#   'clouds': {'all': 67},
#   'cod': 200,
#   'coord': {'lat': -34.53, 'lon': 20.04},
#   'dt': 1602434502,
#   'id': 1015776,
#   'main': {'feels_like': 9.55,
#            'humidity': 55,
#            'pressure': 1022,
#            'temp': 16,
#            'temp_max': 16,
#            'temp_min': 16},
#   'name': 'Bredasdorp',
#   'sys': {'country': 'ZA',
#           'id': 1966,
#           'sunrise': 1602388944,
#           'sunset': 1602435017,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 150, 'speed': 8.2}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -41.87, 'lon': -73.82},
#   'dt': 1602434166,
#   'id': 3899695,
#   'main': {'feels_like': 10.1,
#            'humidity': 62,
#            'pressure': 1025,
#            'temp': 13.18,
#            'temp_max': 13.33,
#            'temp_min': 13},
#   'name': 'Ancud',
#   'sys': {'country': 'CL',
#           'id': 8512,
#           'sunrise': 1602411056,
#           'sunset': 1602457950,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 190, 'speed': 3.1}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 42.1, 'lon': -79.24},
#   'dt': 1602434187,
#   'id': 5122534,
#   'main': {'feels_like': 12.67,
#            'humidity': 71,
#            'pressure': 1020,
#            'temp': 15.44,
#            'temp_max': 17.22,
#            'temp_min': 14},
#   'name': 'Jamestown',
#   'sys': {'country': 'US',
#           'id': 4588,
#           'sunrise': 1602415520,
#           'sunset': 1602456086,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 90, 'speed': 4.1}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -3.8, 'lon': 102.27},
#   'dt': 1602434440,
#   'id': 1649150,
#   'main': {'feels_like': 28.42,
#            'grnd_level': 1007,
#            'humidity': 88,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 24.61,
#            'temp_max': 24.61,
#            'temp_min': 24.61},
#   'name': 'Bengkulu',
#   'sys': {'country': 'ID', 'sunrise': 1602370334, 'sunset': 1602414163},
#   'timezone': 25200,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 334, 'speed': 1.65}},
#  {'base': 'stations',
#   'clouds': {'all': 69},
#   'cod': 200,
#   'coord': {'lat': -8.93, 'lon': 125.41},
#   'dt': 1602434466,
#   'id': 1651810,
#   'main': {'feels_like': 15.1,
#            'grnd_level': 853,
#            'humidity': 88,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 15.17,
#            'temp_max': 15.17,
#            'temp_min': 15.17},
#   'name': 'Airai',
#   'sys': {'country': 'TL', 'sunrise': 1602450995, 'sunset': 1602495166},
#   'timezone': 32400,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 98, 'speed': 1.52}},
#  {'base': 'stations',
#   'clouds': {'all': 62},
#   'cod': 200,
#   'coord': {'lat': 65.58, 'lon': -171},
#   'dt': 1602434567,
#   'id': 4031637,
#   'main': {'feels_like': -4.54,
#            'grnd_level': 1002,
#            'humidity': 88,
#            'pressure': 1004,
#            'sea_level': 1004,
#            'temp': 1.47,
#            'temp_max': 1.47,
#            'temp_min': 1.47},
#   'name': 'Lavrentiya',
#   'sys': {'country': 'RU', 'sunrise': 1602526283, 'sunset': 1602562131},
#   'timezone': 43200,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 359, 'speed': 5.69}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 22.08, 'lon': -159.32},
#   'dt': 1602434457,
#   'id': 5848280,
#   'main': {'feels_like': 24.8,
#            'humidity': 88,
#            'pressure': 1017,
#            'temp': 22.89,
#            'temp_max': 25,
#            'temp_min': 21.67},
#   'name': 'Kapaa',
#   'rain': {'1h': 2.03},
#   'sys': {'country': 'US',
#           'id': 7873,
#           'sunrise': 1602433923,
#           'sunset': 1602476116,
#           'type': 1},
#   'timezone': -36000,
#   'visibility': 10000,
#   'weather': [{'description': 'moderate rain',
#                'icon': '10d',
#                'id': 501,
#                'main': 'Rain'}],
#   'wind': {'deg': 360, 'speed': 3.1}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1602434454,
#   'id': 4030556,
#   'main': {'feels_like': 22.19,
#            'grnd_level': 1020,
#            'humidity': 79,
#            'pressure': 1023,
#            'sea_level': 1023,
#            'temp': 22.95,
#            'temp_max': 22.95,
#            'temp_min': 22.95},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF', 'sunrise': 1602426601, 'sunset': 1602471751},
#   'timezone': -32400,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 81, 'speed': 5.77}},
#  {'base': 'stations',
#   'clouds': {'all': 84},
#   'cod': 200,
#   'coord': {'lat': -0.89, 'lon': 119.87},
#   'dt': 1602434471,
#   'id': 1633034,
#   'main': {'feels_like': 27.73,
#            'grnd_level': 1006,
#            'humidity': 81,
#            'pressure': 1008,
#            'sea_level': 1008,
#            'temp': 24.48,
#            'temp_max': 24.48,
#            'temp_min': 24.48},
#   'name': 'Palu',
#   'sys': {'country': 'ID', 'sunrise': 1602452581, 'sunset': 1602496239},
#   'timezone': 28800,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 116, 'speed': 1.33}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 40.76, 'lon': 48.39},
#   'dt': 1602434616,
#   'id': 587033,
#   'main': {'feels_like': 16.57,
#            'humidity': 67,
#            'pressure': 1024,
#            'temp': 17,
#            'temp_max': 17,
#            'temp_min': 17},
#   'name': 'Basqal',
#   'sys': {'country': 'AZ',
#           'id': 8844,
#           'sunrise': 1602384799,
#           'sunset': 1602425556,
#           'type': 1},
#   'timezone': 14400,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 120, 'speed': 1}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 70.63, 'lon': 29.72},
#   'dt': 1602434617,
#   'id': 780717,
#   'main': {'feels_like': -0.54,
#            'humidity': 100,
#            'pressure': 1016,
#            'temp': 4,
#            'temp_max': 4,
#            'temp_min': 4},
#   'name': 'Båtsfjord',
#   'sys': {'country': 'NO',
#           'id': 1618,
#           'sunrise': 1602392439,
#           'sunset': 1602426876,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 5153,
#   'weather': [{'description': 'drizzle',
#                'icon': '09n',
#                'id': 301,
#                'main': 'Drizzle'}],
#   'wind': {'deg': 50, 'speed': 4.6}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 77},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1602433896,
#   'id': 3833367,
#   'main': {'feels_like': 4,
#            'grnd_level': 987,
#            'humidity': 75,
#            'pressure': 993,
#            'sea_level': 993,
#            'temp': 7.55,
#            'temp_max': 7.55,
#            'temp_min': 7.55},
#   'name': 'Ushuaia',
#   'rain': {'1h': 0.22},
#   'sys': {'country': 'AR', 'sunrise': 1602408725, 'sunset': 1602457631},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 282, 'speed': 3.03}},
#  {'base': 'stations',
#   'clouds': {'all': 13},
#   'cod': 200,
#   'coord': {'lat': -42.78, 'lon': 147.06},
#   'dt': 1602434194,
#   'id': 2155415,
#   'main': {'feels_like': 3.16,
#            'humidity': 86,
#            'pressure': 1020,
#            'temp': 5.49,
#            'temp_max': 6.67,
#            'temp_min': 5},
#   'name': 'New Norfolk',
#   'sys': {'country': 'AU',
#           'id': 2031307,
#           'sunrise': 1602444350,
#           'sunset': 1602491421,
#           'type': 3},
#   'timezone': 39600,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 293, 'speed': 1.27}},
#  {'base': 'stations',
#   'clouds': {'all': 3},
#   'cod': 200,
#   'coord': {'lat': 3.07, 'lon': 172.79},
#   'dt': 1602434489,
#   'id': 2110227,
#   'main': {'feels_like': 27.46,
#            'grnd_level': 1007,
#            'humidity': 74,
#            'pressure': 1008,
#            'sea_level': 1008,
#            'temp': 27.12,
#            'temp_max': 27.12,
#            'temp_min': 27.12},
#   'name': 'Butaritari',
#   'sys': {'country': 'KI', 'sunrise': 1602440006, 'sunset': 1602483417},
#   'timezone': 43200,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 114, 'speed': 6.28}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 70.47, 'lon': -68.59},
#   'dt': 1602434433,
#   'id': 5924351,
#   'main': {'feels_like': -5.8,
#            'humidity': 92,
#            'pressure': 1001,
#            'temp': -1,
#            'temp_max': -1,
#            'temp_min': -1},
#   'name': 'Clyde River',
#   'sys': {'country': 'CA',
#           'id': 776,
#           'sunrise': 1602416063,
#           'sunset': 1602450433,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 320, 'speed': 3.6}},
#  {'base': 'stations',
#   'clouds': {'all': 27},
#   'cod': 200,
#   'coord': {'lat': -53.15, 'lon': -70.92},
#   'dt': 1602434214,
#   'id': 3874787,
#   'main': {'feels_like': -2.12,
#            'humidity': 58,
#            'pressure': 996,
#            'temp': 11.83,
#            'temp_max': 12,
#            'temp_min': 11.67},
#   'name': 'Punta Arenas',
#   'sys': {'country': 'CL',
#           'id': 8487,
#           'sunrise': 1602409516,
#           'sunset': 1602458098,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 280, 'speed': 18}},
#  {'base': 'stations',
#   'clouds': {'all': 17},
#   'cod': 200,
#   'coord': {'lat': 39.05, 'lon': -27.98},
#   'dt': 1602434534,
#   'id': 3372964,
#   'main': {'feels_like': 16.25,
#            'grnd_level': 1025,
#            'humidity': 78,
#            'pressure': 1031,
#            'sea_level': 1031,
#            'temp': 20.11,
#            'temp_max': 20.11,
#            'temp_min': 20.11},
#   'name': 'Lagoa',
#   'sys': {'country': 'PT', 'sunrise': 1602403059, 'sunset': 1602443947},
#   'timezone': 0,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 96, 'speed': 8.44}}]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# df = pd.DataFrame({
#     'City':[city['name'] for city in json_data[0]]
# })
city_name = []
latitude = []
longitude =  []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
for data in json_data:
    try:
        city_name.append(data['name'])
        latitude.append(data['coord']['lat'])
        longitude.append(data['coord']['lon'])
        max_temp.append(data['main']['temp_max'])
        humidity.append(data['main']['humidity'])
        cloudiness.append(data['clouds']['all'])
        wind_speed.append(data['wind']['speed'])
        country.append(data['sys']['country'])
        date.append(data['dt'])
    except:
        pass
    
    
df = pd.DataFrame({
    'City':city_name,
    'Lat':latitude,
    'Lng':longitude,
    'Max Temp':max_temp,
    'Humidity':humidity,
    'Cloudiness':cloudiness,
    'Wind Speed':wind_speed,
    'Country':country,
    'Date':date
})

df.sort_values(by = 'City',ascending = True,inplace = True)
df.reset_index(drop = True,inplace = True)
df
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Abong Mbang   3.98   13.18     21.97        90          90        0.64
# 1          Acarí -15.43  -74.62     25.78        41           6        4.97
# 2       Adelaide -34.93  138.60     18.00        48          17        4.10
# 3          Airai  -8.93  125.41     15.17        88          69        1.52
# 4          Airai  -8.93  125.41     15.17        88          69        1.52
# ..           ...    ...     ...       ...       ...         ...         ...
# 473  Yellowknife  62.46 -114.35      0.56        89          90        5.70
# 474       Yulara -25.24  130.99     20.00        19           1        4.10
# 475       Yulara -25.24  130.99     20.00        19           1        4.10
# 476     Zhaotong  27.32  103.72     10.33        91         100        2.74
# 477     Zyryanka  65.75  150.85     -4.03        87          38        1.86
#
#     Country        Date
# 0        CM  1602434479
# 1        PE  1602434530
# 2        AU  1602434473
# 3        TL  1602434466
# 4        TL  1602434466
# ..      ...         ...
# 473      CA  1602434508
# 474      AU  1602434526
# 475      AU  1602434526
# 476      CN  1602434570
# 477      RU  1602434411
#
# [478 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  478.000000  478.000000  478.000000  478.000000  478.000000  478.000000
# mean     7.392343   -5.179979   15.744247   72.487448   50.035565    4.364017
# std     40.573344  106.808762   10.130958   19.669034   36.504628    3.296459
# min    -54.800000 -175.200000  -11.220000   11.000000    0.000000    0.070000
# 25%    -29.827500  -79.240000    8.330000   61.000000   17.000000    2.460000
# 50%      5.410000  -20.800000   16.110000   75.000000   53.000000    3.560000
# 75%     42.100000  100.340000   24.000000   88.000000   86.000000    5.700000
# max     78.220000  178.420000   39.900000  100.000000  100.000000   18.000000
#
#                Date
# count  4.780000e+02
# mean   1.602434e+09
# std    1.870156e+02
# min    1.602434e+09
# 25%    1.602434e+09
# 50%    1.602434e+09
# 75%    1.602435e+09
# max    1.602435e+09

# %%
df_copy = df.copy()
df_humidity_100 = df_copy.loc[df['Humidity']>=100]
df_humidity_100.index
# Out:
# Int64Index([18, 37, 38, 39, 40, 41, 94, 135, 300, 311, 415, 462], dtype='int64')

# %%
clean_city_data = df_copy.drop(axis=0, index=df_humidity_100.index,inplace=False)
clean_city_data.reset_index(drop = True,inplace = True)
clean_city_data
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Abong Mbang   3.98   13.18     21.97        90          90        0.64
# 1          Acarí -15.43  -74.62     25.78        41           6        4.97
# 2       Adelaide -34.93  138.60     18.00        48          17        4.10
# 3          Airai  -8.93  125.41     15.17        88          69        1.52
# 4          Airai  -8.93  125.41     15.17        88          69        1.52
# ..           ...    ...     ...       ...       ...         ...         ...
# 461  Yellowknife  62.46 -114.35      0.56        89          90        5.70
# 462       Yulara -25.24  130.99     20.00        19           1        4.10
# 463       Yulara -25.24  130.99     20.00        19           1        4.10
# 464     Zhaotong  27.32  103.72     10.33        91         100        2.74
# 465     Zyryanka  65.75  150.85     -4.03        87          38        1.86
#
#     Country        Date
# 0        CM  1602434479
# 1        PE  1602434530
# 2        AU  1602434473
# 3        TL  1602434466
# 4        TL  1602434466
# ..      ...         ...
# 461      CA  1602434508
# 462      AU  1602434526
# 463      AU  1602434526
# 464      CN  1602434570
# 465      RU  1602434411
#
# [466 rows x 9 columns]

# %%
clean_city_data['City'].value_counts()
# Out:
# Ushuaia          23
# Rikitea          18
# Vaini            12
# Punta Arenas     12
# Mataura          11
#                  ..
# Alta Floresta     1
# Big Spring        1
# Pochutla          1
# Kenai             1
# Bestöbe           1
# Name: City, Length: 236, dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
clean_city_data.plot(kind='scatter',x = 'Lat',y ='Max Temp' )
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
clean_city_data.plot(kind='scatter',x = 'Lat',y ='Humidity' )
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
clean_city_data.plot(kind='scatter',x = 'Lat',y ='Cloudiness' )
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
clean_city_data.plot(kind='scatter',x = 'Lat',y ='Wind Speed' )
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
north_hem = clean_city_data.copy()
north_hem = north_hem.loc[north_hem['Lng'] > 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_hem.plot(kind = 'scatter',x = 'Lat',y = 'Max Temp')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_hem = clean_city_data.copy()
south_hem = south_hem.loc[south_hem['Lng'] < 0]
south_hem.plot(kind = 'scatter',x = 'Lat',y = 'Max Temp')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_hem.plot(kind = 'scatter',x = 'Lat',y = 'Humidity')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_hem.plot(kind = 'scatter',x = 'Lat',y = 'Humidity')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_hem.plot(kind = 'scatter',x = 'Lat',y = 'Cloudiness')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_hem.plot(kind = 'scatter',x = 'Lat',y = 'Cloudiness')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_hem.plot(kind = 'scatter',x = 'Lat',y = 'Wind Speed')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_hem.plot(kind = 'scatter',x = 'Lat',y = 'Wind Speed')
plt.show()
