# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import requests
from pprint import pprint
import json
import os
from citipy import citipy
import random
import numpy
import pandas as pd
# API_KEY = os.environ.get('API_WEATHER_KEY')
API_KEY = '726f6729b1b0ce3ac75298331adb8ac7'
URL = "https://api.openweathermap.org/data/2.5/weather?"
parameters = {
    'q' : 'Perth',
    'appid' : API_KEY,
    'units':'metric'
    
}
data_request = requests.get(URL,params =parameters ).json()
data = pprint(data_request)
data
# Out:
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -31.93, 'lon': 115.83},
#  'dt': 1602423857,
#  'id': 2063523,
#  'main': {'feels_like': 12.23,
#           'humidity': 67,
#           'pressure': 1018,
#           'temp': 16.44,
#           'temp_max': 17,
#           'temp_min': 16},
#  'name': 'Perth',
#  'sys': {'country': 'AU',
#          'id': 9586,
#          'sunrise': 1602366094,
#          'sunset': 1602411896,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 200, 'speed': 6.2}}

# %%
dir(citipy)
# Out:
# ['City',
#  'WORLD_CITIES_DICT',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_current_dir',
#  '_current_filename',
#  '_world_cities_csv_path',
#  '_world_cities_kdtree',
#  'c',
#  'cities',
#  'city',
#  'city_coordinate_key',
#  'csv',
#  'csv_file',
#  'kdtree',
#  'nearest_city',
#  'os']

# %%
city = citipy.nearest_city(22.99, 120.21)
city.city_name
# Out:
# 'tainan'

# %%
random.seed(5)
ran_lat= [random.uniform(-90,90) for _ in range(50)]
ran_long = [random.uniform(-180,180) for _ in range(50)]
dd = list(zip(ran_lat,ran_long))
dd
# Out:
# [(22.122305080146347, -58.357129813968555),
#  (43.52165806693128, -68.41514462287364),
#  (53.13484180182539, 114.66650687294549),
#  (79.64105107986904, -6.931732813185988),
#  (43.18174345318752, -66.31448189528014),
#  (76.01849939977507, -6.76138095472902),
#  (-84.77905890894935, 73.68088829072732),
#  (-6.187922211941043, -159.47966536711562),
#  (79.80420905969646, 171.03584273192473),
#  (26.815419564646362, -171.76839722902054),
#  (72.16208851511209, 89.9262080248584),
#  (-69.62292636243401, 124.15712017972669),
#  (-5.567571399210522, -173.49568726372917),
#  (-45.61689012843054, 103.58578943295629),
#  (7.876954662467483, -48.17358869693021),
#  (13.309413827058137, 28.266778460474853),
#  (-87.6394458739976, -176.73178074496977),
#  (-50.988635916507334, -163.17823726838105),
#  (-39.693174118000144, -114.86898433762278),
#  (74.94216692553934, 163.86476385281986),
#  (47.8305812932455, -109.25219861531706),
#  (-61.27124177555312, 92.06510848247439),
#  (53.486458457616806, 154.67591505510762),
#  (-65.02186468819744, 159.1357785939718),
#  (21.14145368390099, -56.02254730091569),
#  (-67.19413814095145, -52.274446179151596),
#  (-89.68052480354376, 8.892655449523204),
#  (66.85285405037078, 99.21708529163828),
#  (-52.29785115087878, -141.10096713666016),
#  (-51.213389539548196, 89.42330033447871),
#  (86.83579958866656, 107.00160393287979),
#  (67.03339777862433, 129.48995490752884),
#  (-37.92506980555323, -166.8126312205821),
#  (83.06603801101502, 160.48806661518614),
#  (7.060224396745909, -147.17524889816332),
#  (32.009485905106615, -57.33340721847999),
#  (-53.13968738391729, 39.897913713344735),
#  (79.37568019583983, 150.51138679199238),
#  (34.31554939924348, -57.61457041469595),
#  (83.98157621709518, 152.71114299400466),
#  (70.87350196376613, 16.251853355365995),
#  (-36.217998386303805, -67.51786703655351),
#  (-24.98581174997085, -65.95200516118422),
#  (-60.12790971664579, -116.10800081820412),
#  (-63.77365628267715, -151.84935640059354),
#  (-78.27485159237827, -126.40750393563053),
#  (-35.75536186149675, 68.10285144559506),
#  (18.559799533377785, 178.8216532332134),
#  (-89.39103851261578, -121.84939280713814),
#  (32.02816491858442, -162.52122112255574)]

# %%
cities = []
def generate_cities(lat):
    for rows in lat:
        city = citipy.nearest_city(rows[0],rows[1])
        cities.append(city.city_name)

generate_cities(dd)
cities
# Out:
# ['codrington',
#  'bar harbor',
#  'verkh-usugli',
#  'husavik',
#  'yarmouth',
#  'klaksvik',
#  'taolanaro',
#  'faanui',
#  'pevek',
#  'kapaa',
#  'talnakh',
#  'albany',
#  'sataua',
#  'busselton',
#  'cayenne',
#  'abu zabad',
#  'vaini',
#  'avarua',
#  'rikitea',
#  'cherskiy',
#  'lewistown',
#  'busselton',
#  'sobolevo',
#  'bluff',
#  'codrington',
#  'ushuaia',
#  'hermanus',
#  'tura',
#  'rikitea',
#  'busselton',
#  'khatanga',
#  'batagay-alyta',
#  'avarua',
#  'cherskiy',
#  'hilo',
#  'saint george',
#  'east london',
#  'chokurdakh',
#  'saint george',
#  'chokurdakh',
#  'andenes',
#  'san rafael',
#  'salta',
#  'rikitea',
#  'mataura',
#  'rikitea',
#  'mahebourg',
#  'butaritari',
#  'punta arenas',
#  'kapaa']

# %% [markdown]
# ## Generate Cities List

# %%
json_data = []
def get_weather_data(cities,set_num):
    print("""Beginning Data Retrieval     
---------------------------------------""")
    for enum,city in enumerate(cities,start=1):  
        parameters = {
            'q' : city,
            'appid' : API_KEY,
            'units':'metric'

        }
        try:
            
            data_request = requests.get(URL,params =parameters ).json()
            print(f"Processing Record {enum} of Set {set_num} | {data_request['name']}")
            
            
        except:
            print("City not found. Skipping...")
        finally:
            json_data.append(data_request)
    print("""-----------------------------
Data Retrieval Complete      
-----------------------------""")
get_weather_data(cities,1)
type(json_data)
# Out:
# Beginning Data Retrieval
# ---------------------------------------
# Processing Record 1 of Set 1 | Codrington
# Processing Record 2 of Set 1 | Bar Harbor
# Processing Record 3 of Set 1 | Verkh-Usugli
# Processing Record 4 of Set 1 | Husavik
# Processing Record 5 of Set 1 | Yarmouth
# Processing Record 6 of Set 1 | Klaksvík
# City not found. Skipping...
# Processing Record 8 of Set 1 | Faanui
# Processing Record 9 of Set 1 | Pevek
# Processing Record 10 of Set 1 | Kapaa
# Processing Record 11 of Set 1 | Talnakh
# Processing Record 12 of Set 1 | Albany
# City not found. Skipping...
# Processing Record 14 of Set 1 | Busselton
# Processing Record 15 of Set 1 | Cayenne
# Processing Record 16 of Set 1 | Abū Zabad
# Processing Record 17 of Set 1 | Vaini
# Processing Record 18 of Set 1 | Avarua
# Processing Record 19 of Set 1 | Rikitea
# Processing Record 20 of Set 1 | Cherskiy
# Processing Record 21 of Set 1 | Lewistown
# Processing Record 22 of Set 1 | Busselton
# Processing Record 23 of Set 1 | Sobolevo
# Processing Record 24 of Set 1 | Bluff
# Processing Record 25 of Set 1 | Codrington
# Processing Record 26 of Set 1 | Ushuaia
# Processing Record 27 of Set 1 | Hermanus
# Processing Record 28 of Set 1 | Tura
# Processing Record 29 of Set 1 | Rikitea
# Processing Record 30 of Set 1 | Busselton
# Processing Record 31 of Set 1 | Khatanga
# Processing Record 32 of Set 1 | Batagay-Alyta
# Processing Record 33 of Set 1 | Avarua
# Processing Record 34 of Set 1 | Cherskiy
# Processing Record 35 of Set 1 | Hilo
# Processing Record 36 of Set 1 | Saint George
# Processing Record 37 of Set 1 | East London
# Processing Record 38 of Set 1 | Chokurdakh
# Processing Record 39 of Set 1 | Saint George
# Processing Record 40 of Set 1 | Chokurdakh
# Processing Record 41 of Set 1 | Andenes
# Processing Record 42 of Set 1 | San Rafael
# Processing Record 43 of Set 1 | Salta
# Processing Record 44 of Set 1 | Rikitea
# Processing Record 45 of Set 1 | Mataura
# Processing Record 46 of Set 1 | Rikitea
# Processing Record 47 of Set 1 | Mahébourg
# Processing Record 48 of Set 1 | Butaritari
# Processing Record 49 of Set 1 | Punta Arenas
# Processing Record 50 of Set 1 | Kapaa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# list

# %%
json_data
# Out:
# [{'coord': {'lon': 141.97, 'lat': -38.27},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 7.08,
#    'feels_like': 3.55,
#    'temp_min': 7.08,
#    'temp_max': 7.08,
#    'pressure': 1022,
#    'humidity': 91,
#    'sea_level': 1022,
#    'grnd_level': 1021},
#   'visibility': 10000,
#   'wind': {'speed': 3.64, 'deg': 51},
#   'clouds': {'all': 0},
#   'dt': 1602425948,
#   'sys': {'country': 'AU', 'sunrise': 1602445834, 'sunset': 1602492380},
#   'timezone': 39600,
#   'id': 2171099,
#   'name': 'Codrington',
#   'cod': 200},
#  {'coord': {'lon': -68.2, 'lat': 44.39},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 9.61,
#    'feels_like': 4.99,
#    'temp_min': 9,
#    'temp_max': 10.56,
#    'pressure': 1020,
#    'humidity': 66},
#   'visibility': 4828,
#   'wind': {'speed': 4.6, 'deg': 340, 'gust': 9.3},
#   'clouds': {'all': 75},
#   'dt': 1602425948,
#   'sys': {'type': 1,
#    'id': 3431,
#    'country': 'US',
#    'sunrise': 1602412991,
#    'sunset': 1602453317},
#   'timezone': -14400,
#   'id': 4957320,
#   'name': 'Bar Harbor',
#   'cod': 200},
#  {'coord': {'lon': 115.17, 'lat': 52.7},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': -4.85,
#    'feels_like': -8.73,
#    'temp_min': -4.85,
#    'temp_max': -4.85,
#    'pressure': 1017,
#    'humidity': 85,
#    'sea_level': 1017,
#    'grnd_level': 912},
#   'visibility': 10000,
#   'wind': {'speed': 1.53, 'deg': 279},
#   'clouds': {'all': 2},
#   'dt': 1602425680,
#   'sys': {'country': 'RU', 'sunrise': 1602369467, 'sunset': 1602408840},
#   'timezone': 32400,
#   'id': 2013459,
#   'name': 'Verkh-Usugli',
#   'cod': 200},
#  {'coord': {'lon': -17.34, 'lat': 66.04},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 9,
#    'feels_like': 4.08,
#    'temp_min': 9,
#    'temp_max': 9,
#    'pressure': 1014,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 140},
#   'rain': {'1h': 0.96},
#   'clouds': {'all': 75},
#   'dt': 1602425949,
#   'sys': {'type': 1,
#    'id': 83,
#    'country': 'IS',
#    'sunrise': 1602402806,
#    'sunset': 1602439094},
#   'timezone': 0,
#   'id': 2629833,
#   'name': 'Husavik',
#   'cod': 200},
#  {'coord': {'lon': -70.23, 'lat': 41.71},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 15.76,
#    'feels_like': 9.85,
#    'temp_min': 15.56,
#    'temp_max': 16.11,
#    'pressure': 1020,
#    'humidity': 59},
#   'visibility': 10000,
#   'wind': {'speed': 7.7, 'deg': 360, 'gust': 10.8},
#   'clouds': {'all': 20},
#   'dt': 1602425949,
#   'sys': {'type': 1,
#    'id': 4454,
#    'country': 'US',
#    'sunrise': 1602413336,
#    'sunset': 1602453946},
#   'timezone': -14400,
#   'id': 4956335,
#   'name': 'Yarmouth',
#   'cod': 200},
#  {'coord': {'lon': -6.59, 'lat': 62.23},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 7,
#    'feels_like': 4.4,
#    'temp_min': 7,
#    'temp_max': 7,
#    'pressure': 1025,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 250},
#   'clouds': {'all': 100},
#   'dt': 1602425950,
#   'sys': {'type': 1,
#    'id': 1596,
#    'country': 'FO',
#    'sunrise': 1602399659,
#    'sunset': 1602437082},
#   'timezone': 3600,
#   'id': 2618795,
#   'name': 'Klaksvík',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -151.75, 'lat': -16.48},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 25.89,
#    'feels_like': 25.35,
#    'temp_min': 25.89,
#    'temp_max': 25.89,
#    'pressure': 1013,
#    'humidity': 80,
#    'sea_level': 1013,
#    'grnd_level': 1004},
#   'visibility': 10000,
#   'wind': {'speed': 7.62, 'deg': 69},
#   'rain': {'1h': 0.13},
#   'clouds': {'all': 74},
#   'dt': 1602425950,
#   'sys': {'country': 'PF', 'sunrise': 1602430868, 'sunset': 1602475537},
#   'timezone': -36000,
#   'id': 4034551,
#   'name': 'Faanui',
#   'cod': 200},
#  {'coord': {'lon': 170.31, 'lat': 69.7},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': -1.72,
#    'feels_like': -5.1,
#    'temp_min': -1.72,
#    'temp_max': -1.72,
#    'pressure': 1024,
#    'humidity': 93,
#    'sea_level': 1024,
#    'grnd_level': 1018},
#   'visibility': 10000,
#   'wind': {'speed': 1.48, 'deg': 336},
#   'clouds': {'all': 91},
#   'dt': 1602425791,
#   'sys': {'country': 'RU', 'sunrise': 1602445019, 'sunset': 1602479595},
#   'timezone': 43200,
#   'id': 2122090,
#   'name': 'Pevek',
#   'cod': 200},
#  {'coord': {'lon': -159.32, 'lat': 22.08},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 23.04,
#    'feels_like': 25.26,
#    'temp_min': 22.22,
#    'temp_max': 25,
#    'pressure': 1017,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 280},
#   'clouds': {'all': 75},
#   'dt': 1602425951,
#   'sys': {'type': 1,
#    'id': 7873,
#    'country': 'US',
#    'sunrise': 1602433923,
#    'sunset': 1602476116},
#   'timezone': -36000,
#   'id': 5848280,
#   'name': 'Kapaa',
#   'cod': 200},
#  {'coord': {'lon': 88.4, 'lat': 69.49},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'stations',
#   'main': {'temp': -5,
#    'feels_like': -16.12,
#    'temp_min': -5,
#    'temp_max': -5,
#    'pressure': 1014,
#    'humidity': 92},
#   'visibility': 2700,
#   'wind': {'speed': 12, 'deg': 190},
#   'clouds': {'all': 75},
#   'dt': 1602425951,
#   'sys': {'type': 1,
#    'id': 8951,
#    'country': 'RU',
#    'sunrise': 1602378040,
#    'sunset': 1602413114},
#   'timezone': 25200,
#   'id': 1490256,
#   'name': 'Talnakh',
#   'cod': 200},
#  {'coord': {'lon': -73.97, 'lat': 42.6},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 10.12,
#    'feels_like': 5.83,
#    'temp_min': 9.44,
#    'temp_max': 11.11,
#    'pressure': 1021,
#    'humidity': 57},
#   'visibility': 10000,
#   'wind': {'speed': 3.73, 'deg': 24},
#   'clouds': {'all': 22},
#   'dt': 1602425951,
#   'sys': {'type': 3,
#    'id': 19530,
#    'country': 'US',
#    'sunrise': 1602414281,
#    'sunset': 1602454797},
#   'timezone': -14400,
#   'id': 5106841,
#   'name': 'Albany',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 115.33, 'lat': -33.65},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 11.37,
#    'feels_like': 7.53,
#    'temp_min': 10,
#    'temp_max': 12.78,
#    'pressure': 1013,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 3.76, 'deg': 168},
#   'clouds': {'all': 0},
#   'dt': 1602425952,
#   'sys': {'type': 3,
#    'id': 2011706,
#    'country': 'AU',
#    'sunrise': 1602366136,
#    'sunset': 1602412094},
#   'timezone': 28800,
#   'id': 2075265,
#   'name': 'Busselton',
#   'cod': 200},
#  {'coord': {'lon': -52.33, 'lat': 4.93},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 32,
#    'feels_like': 33.73,
#    'temp_min': 32,
#    'temp_max': 32,
#    'pressure': 1014,
#    'humidity': 55},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 70},
#   'clouds': {'all': 20},
#   'dt': 1602425952,
#   'sys': {'type': 1,
#    'id': 8669,
#    'country': 'GF',
#    'sunrise': 1602407695,
#    'sunset': 1602450997},
#   'timezone': -10800,
#   'id': 3382160,
#   'name': 'Cayenne',
#   'cod': 200},
#  {'coord': {'lon': 29.25, 'lat': 12.35},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 33.18,
#    'feels_like': 32.79,
#    'temp_min': 33.18,
#    'temp_max': 33.18,
#    'pressure': 1005,
#    'humidity': 34,
#    'sea_level': 1005,
#    'grnd_level': 945},
#   'visibility': 10000,
#   'wind': {'speed': 2.96, 'deg': 151},
#   'rain': {'1h': 0.19},
#   'clouds': {'all': 100},
#   'dt': 1602425953,
#   'sys': {'country': 'SD', 'sunrise': 1602388343, 'sunset': 1602431198},
#   'timezone': 7200,
#   'id': 380348,
#   'name': 'Abū Zabad',
#   'cod': 200},
#  {'coord': {'lon': -175.2, 'lat': -21.2},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 24,
#    'feels_like': 24.79,
#    'temp_min': 24,
#    'temp_max': 24,
#    'pressure': 1019,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 120},
#   'clouds': {'all': 20},
#   'dt': 1602425953,
#   'sys': {'type': 1,
#    'id': 7285,
#    'country': 'TO',
#    'sunrise': 1602522672,
#    'sunset': 1602567757},
#   'timezone': 46800,
#   'id': 4032243,
#   'name': 'Vaini',
#   'cod': 200},
#  {'coord': {'lon': -159.78, 'lat': -21.21},
#   'weather': [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': 22,
#    'feels_like': 24.01,
#    'temp_min': 22,
#    'temp_max': 22,
#    'pressure': 1013,
#    'humidity': 94},
#   'visibility': 400,
#   'wind': {'speed': 3.1, 'deg': 210},
#   'clouds': {'all': 96},
#   'dt': 1602425953,
#   'sys': {'type': 1,
#    'id': 7271,
#    'country': 'CK',
#    'sunrise': 1602432624,
#    'sunset': 1602477635},
#   'timezone': -36000,
#   'id': 4035715,
#   'name': 'Avarua',
#   'cod': 200},
#  {'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 22.75,
#    'feels_like': 21.77,
#    'temp_min': 22.75,
#    'temp_max': 22.75,
#    'pressure': 1021,
#    'humidity': 80,
#    'sea_level': 1021,
#    'grnd_level': 1018},
#   'visibility': 10000,
#   'wind': {'speed': 6.09, 'deg': 83},
#   'clouds': {'all': 0},
#   'dt': 1602425954,
#   'sys': {'country': 'PF', 'sunrise': 1602426601, 'sunset': 1602471751},
#   'timezone': -32400,
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'coord': {'lon': 161.3, 'lat': 68.75},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': -7.31,
#    'feels_like': -12.8,
#    'temp_min': -7.31,
#    'temp_max': -7.31,
#    'pressure': 1022,
#    'humidity': 94,
#    'sea_level': 1022,
#    'grnd_level': 1022},
#   'visibility': 10000,
#   'wind': {'speed': 3.69, 'deg': 135},
#   'clouds': {'all': 23},
#   'dt': 1602425954,
#   'sys': {'country': 'RU', 'sunrise': 1602446966, 'sunset': 1602481971},
#   'timezone': 39600,
#   'id': 2126199,
#   'name': 'Cherskiy',
#   'cod': 200},
#  {'coord': {'lon': -77.57, 'lat': 40.6},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 16.84,
#    'feels_like': 16.23,
#    'temp_min': 16.11,
#    'temp_max': 18,
#    'pressure': 1019,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 70},
#   'clouds': {'all': 90},
#   'dt': 1602425669,
#   'sys': {'type': 1,
#    'id': 5732,
#    'country': 'US',
#    'sunrise': 1602415044,
#    'sunset': 1602455761},
#   'timezone': -14400,
#   'id': 5197850,
#   'name': 'Lewistown',
#   'cod': 200},
#  {'coord': {'lon': 115.33, 'lat': -33.65},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 11.37,
#    'feels_like': 7.53,
#    'temp_min': 10,
#    'temp_max': 12.78,
#    'pressure': 1013,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 3.76, 'deg': 168},
#   'clouds': {'all': 0},
#   'dt': 1602425952,
#   'sys': {'type': 3,
#    'id': 2011706,
#    'country': 'AU',
#    'sunrise': 1602366136,
#    'sunset': 1602412094},
#   'timezone': 28800,
#   'id': 2075265,
#   'name': 'Busselton',
#   'cod': 200},
#  {'coord': {'lon': 31.9, 'lat': 54.43},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 12.9,
#    'feels_like': 10.76,
#    'temp_min': 12.9,
#    'temp_max': 12.9,
#    'pressure': 1016,
#    'humidity': 79,
#    'sea_level': 1016,
#    'grnd_level': 993},
#   'visibility': 10000,
#   'wind': {'speed': 2.88, 'deg': 113},
#   'rain': {'1h': 0.133},
#   'clouds': {'all': 100},
#   'dt': 1602425955,
#   'sys': {'country': 'RU', 'sunrise': 1602389612, 'sunset': 1602428657},
#   'timezone': 10800,
#   'id': 525426,
#   'name': 'Sobolevo',
#   'cod': 200},
#  {'coord': {'lon': 168.33, 'lat': -46.6},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 11.67,
#    'feels_like': 8.08,
#    'temp_min': 11.67,
#    'temp_max': 11.67,
#    'pressure': 1014,
#    'humidity': 92},
#   'visibility': 10000,
#   'wind': {'speed': 5.36, 'deg': 235, 'gust': 8.49},
#   'clouds': {'all': 94},
#   'dt': 1602425955,
#   'sys': {'type': 3,
#    'id': 2008959,
#    'country': 'NZ',
#    'sunrise': 1602438994,
#    'sunset': 1602486570},
#   'timezone': 46800,
#   'id': 2206939,
#   'name': 'Bluff',
#   'cod': 200},
#  {'coord': {'lon': 141.97, 'lat': -38.27},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 7.08,
#    'feels_like': 3.55,
#    'temp_min': 7.08,
#    'temp_max': 7.08,
#    'pressure': 1022,
#    'humidity': 91,
#    'sea_level': 1022,
#    'grnd_level': 1021},
#   'visibility': 10000,
#   'wind': {'speed': 3.64, 'deg': 51},
#   'clouds': {'all': 0},
#   'dt': 1602425948,
#   'sys': {'country': 'AU', 'sunrise': 1602445834, 'sunset': 1602492380},
#   'timezone': 39600,
#   'id': 2171099,
#   'name': 'Codrington',
#   'cod': 200},
#  {'coord': {'lon': -68.3, 'lat': -54.8},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 11,
#    'feels_like': 7.95,
#    'temp_min': 11,
#    'temp_max': 11,
#    'pressure': 992,
#    'humidity': 64},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 180},
#   'clouds': {'all': 40},
#   'dt': 1602425709,
#   'sys': {'type': 1,
#    'id': 8303,
#    'country': 'AR',
#    'sunrise': 1602408725,
#    'sunset': 1602457631},
#   'timezone': -10800,
#   'id': 3833367,
#   'name': 'Ushuaia',
#   'cod': 200},
#  {'coord': {'lon': 19.23, 'lat': -34.42},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 20,
#    'feels_like': 17.5,
#    'temp_min': 20,
#    'temp_max': 20,
#    'pressure': 1021,
#    'humidity': 48},
#   'visibility': 10000,
#   'wind': {'speed': 3.13, 'deg': 94, 'gust': 7.15},
#   'clouds': {'all': 98},
#   'dt': 1602425956,
#   'sys': {'type': 3,
#    'id': 2006131,
#    'country': 'ZA',
#    'sunrise': 1602389143,
#    'sunset': 1602435206},
#   'timezone': 7200,
#   'id': 3366880,
#   'name': 'Hermanus',
#   'cod': 200},
#  {'coord': {'lon': 90.22, 'lat': 25.52},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 24.19,
#    'feels_like': 28.77,
#    'temp_min': 24.19,
#    'temp_max': 24.19,
#    'pressure': 1004,
#    'humidity': 91,
#    'sea_level': 1004,
#    'grnd_level': 962},
#   'visibility': 10000,
#   'wind': {'speed': 0.65, 'deg': 72},
#   'clouds': {'all': 95},
#   'dt': 1602425794,
#   'sys': {'country': 'IN', 'sunrise': 1602374135, 'sunset': 1602416145},
#   'timezone': 19800,
#   'id': 1254046,
#   'name': 'Tura',
#   'cod': 200},
#  {'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 22.75,
#    'feels_like': 21.77,
#    'temp_min': 22.75,
#    'temp_max': 22.75,
#    'pressure': 1021,
#    'humidity': 80,
#    'sea_level': 1021,
#    'grnd_level': 1018},
#   'visibility': 10000,
#   'wind': {'speed': 6.09, 'deg': 83},
#   'clouds': {'all': 0},
#   'dt': 1602425954,
#   'sys': {'country': 'PF', 'sunrise': 1602426601, 'sunset': 1602471751},
#   'timezone': -32400,
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'coord': {'lon': 115.33, 'lat': -33.65},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 11.37,
#    'feels_like': 7.53,
#    'temp_min': 10,
#    'temp_max': 12.78,
#    'pressure': 1013,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 3.76, 'deg': 168},
#   'clouds': {'all': 0},
#   'dt': 1602425952,
#   'sys': {'type': 3,
#    'id': 2011706,
#    'country': 'AU',
#    'sunrise': 1602366136,
#    'sunset': 1602412094},
#   'timezone': 28800,
#   'id': 2075265,
#   'name': 'Busselton',
#   'cod': 200},
#  {'coord': {'lon': 102.5, 'lat': 71.97},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'stations',
#   'main': {'temp': -6.05,
#    'feels_like': -12.59,
#    'temp_min': -6.05,
#    'temp_max': -6.05,
#    'pressure': 1014,
#    'humidity': 98,
#    'sea_level': 1014,
#    'grnd_level': 1011},
#   'visibility': 375,
#   'wind': {'speed': 5.43, 'deg': 223},
#   'snow': {'1h': 0.13},
#   'clouds': {'all': 100},
#   'dt': 1602425955,
#   'sys': {'country': 'RU', 'sunrise': 1602375285, 'sunset': 1602409102},
#   'timezone': 25200,
#   'id': 2022572,
#   'name': 'Khatanga',
#   'cod': 200},
#  {'coord': {'lon': 130.41, 'lat': 67.8},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': -9.11,
#    'feels_like': -12.91,
#    'temp_min': -9.11,
#    'temp_max': -9.11,
#    'pressure': 1018,
#    'humidity': 85,
#    'sea_level': 1018,
#    'grnd_level': 954},
#   'visibility': 10000,
#   'wind': {'speed': 0.94, 'deg': 2},
#   'clouds': {'all': 73},
#   'dt': 1602425957,
#   'sys': {'country': 'RU', 'sunrise': 1602367579, 'sunset': 1602403414},
#   'timezone': 32400,
#   'id': 2027042,
#   'name': 'Batagay-Alyta',
#   'cod': 200},
#  {'coord': {'lon': -159.78, 'lat': -21.21},
#   'weather': [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': 22,
#    'feels_like': 24.01,
#    'temp_min': 22,
#    'temp_max': 22,
#    'pressure': 1013,
#    'humidity': 94},
#   'visibility': 400,
#   'wind': {'speed': 3.1, 'deg': 210},
#   'clouds': {'all': 96},
#   'dt': 1602425953,
#   'sys': {'type': 1,
#    'id': 7271,
#    'country': 'CK',
#    'sunrise': 1602432624,
#    'sunset': 1602477635},
#   'timezone': -36000,
#   'id': 4035715,
#   'name': 'Avarua',
#   'cod': 200},
#  {'coord': {'lon': 161.3, 'lat': 68.75},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': -7.31,
#    'feels_like': -12.8,
#    'temp_min': -7.31,
#    'temp_max': -7.31,
#    'pressure': 1022,
#    'humidity': 94,
#    'sea_level': 1022,
#    'grnd_level': 1022},
#   'visibility': 10000,
#   'wind': {'speed': 3.69, 'deg': 135},
#   'clouds': {'all': 23},
#   'dt': 1602425954,
#   'sys': {'country': 'RU', 'sunrise': 1602446966, 'sunset': 1602481971},
#   'timezone': 39600,
#   'id': 2126199,
#   'name': 'Cherskiy',
#   'cod': 200},
#  {'coord': {'lon': -155.09, 'lat': 19.73},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 17.07,
#    'feels_like': 15.23,
#    'temp_min': 8.33,
#    'temp_max': 21,
#    'pressure': 1016,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 240},
#   'clouds': {'all': 1},
#   'dt': 1602425787,
#   'sys': {'type': 1,
#    'id': 7881,
#    'country': 'US',
#    'sunrise': 1602432827,
#    'sunset': 1602475181},
#   'timezone': -36000,
#   'id': 5855927,
#   'name': 'Hilo',
#   'cod': 200},
#  {'coord': {'lon': -113.58, 'lat': 37.1},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 14.42,
#    'feels_like': 10.04,
#    'temp_min': 13.89,
#    'temp_max': 15,
#    'pressure': 1014,
#    'humidity': 33},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 10},
#   'clouds': {'all': 1},
#   'dt': 1602425959,
#   'sys': {'type': 1,
#    'id': 5832,
#    'country': 'US',
#    'sunrise': 1602423527,
#    'sunset': 1602464560},
#   'timezone': -21600,
#   'id': 5546220,
#   'name': 'Saint George',
#   'cod': 200},
#  {'coord': {'lon': 27.91, 'lat': -33.02},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 16,
#    'feels_like': 13.36,
#    'temp_min': 16,
#    'temp_max': 16,
#    'pressure': 1025,
#    'humidity': 59},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 150},
#   'clouds': {'all': 75},
#   'dt': 1602425959,
#   'sys': {'type': 1,
#    'id': 1912,
#    'country': 'ZA',
#    'sunrise': 1602387127,
#    'sunset': 1602433057},
#   'timezone': 7200,
#   'id': 1006984,
#   'name': 'East London',
#   'cod': 200},
#  {'coord': {'lon': 147.92, 'lat': 70.63},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': -8.34,
#    'feels_like': -12.28,
#    'temp_min': -8.34,
#    'temp_max': -8.34,
#    'pressure': 1019,
#    'humidity': 95,
#    'sea_level': 1019,
#    'grnd_level': 1014},
#   'visibility': 10000,
#   'wind': {'speed': 1.38, 'deg': 16},
#   'clouds': {'all': 15},
#   'dt': 1602425959,
#   'sys': {'country': 'RU', 'sunrise': 1602450645, 'sunset': 1602484713},
#   'timezone': 39600,
#   'id': 2126123,
#   'name': 'Chokurdakh',
#   'cod': 200},
#  {'coord': {'lon': -113.58, 'lat': 37.1},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 14.42,
#    'feels_like': 10.04,
#    'temp_min': 13.89,
#    'temp_max': 15,
#    'pressure': 1014,
#    'humidity': 33},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 10},
#   'clouds': {'all': 1},
#   'dt': 1602425959,
#   'sys': {'type': 1,
#    'id': 5832,
#    'country': 'US',
#    'sunrise': 1602423527,
#    'sunset': 1602464560},
#   'timezone': -21600,
#   'id': 5546220,
#   'name': 'Saint George',
#   'cod': 200},
#  {'coord': {'lon': 147.92, 'lat': 70.63},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': -8.34,
#    'feels_like': -12.28,
#    'temp_min': -8.34,
#    'temp_max': -8.34,
#    'pressure': 1019,
#    'humidity': 95,
#    'sea_level': 1019,
#    'grnd_level': 1014},
#   'visibility': 10000,
#   'wind': {'speed': 1.38, 'deg': 16},
#   'clouds': {'all': 15},
#   'dt': 1602425959,
#   'sys': {'country': 'RU', 'sunrise': 1602450645, 'sunset': 1602484713},
#   'timezone': 39600,
#   'id': 2126123,
#   'name': 'Chokurdakh',
#   'cod': 200},
#  {'coord': {'lon': 16.12, 'lat': 69.31},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 8,
#    'feels_like': 3.08,
#    'temp_min': 8,
#    'temp_max': 8,
#    'pressure': 1018,
#    'humidity': 75},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 20},
#   'clouds': {'all': 75},
#   'dt': 1602425664,
#   'sys': {'type': 1,
#    'id': 1603,
#    'country': 'NO',
#    'sunrise': 1602395395,
#    'sunset': 1602430447},
#   'timezone': 7200,
#   'id': 3163146,
#   'name': 'Andenes',
#   'cod': 200},
#  {'coord': {'lon': -68.33, 'lat': -34.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 16.98,
#    'feels_like': 11.58,
#    'temp_min': 16.98,
#    'temp_max': 16.98,
#    'pressure': 1021,
#    'humidity': 28,
#    'sea_level': 1021,
#    'grnd_level': 942},
#   'visibility': 10000,
#   'wind': {'speed': 4.55, 'deg': 350},
#   'clouds': {'all': 0},
#   'dt': 1602425960,
#   'sys': {'country': 'AR', 'sunrise': 1602410129, 'sunset': 1602456242},
#   'timezone': -10800,
#   'id': 3836669,
#   'name': 'San Rafael',
#   'cod': 200},
#  {'coord': {'lon': -65.41, 'lat': -24.79},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 26,
#    'feels_like': 23.18,
#    'temp_min': 26,
#    'temp_max': 26,
#    'pressure': 1020,
#    'humidity': 24},
#   'visibility': 8000,
#   'wind': {'speed': 2.1, 'deg': 70},
#   'clouds': {'all': 0},
#   'dt': 1602425961,
#   'sys': {'type': 1,
#    'id': 8267,
#    'country': 'AR',
#    'sunrise': 1602409853,
#    'sunset': 1602455116},
#   'timezone': -10800,
#   'id': 3838233,
#   'name': 'Salta',
#   'cod': 200},
#  {'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 22.75,
#    'feels_like': 21.77,
#    'temp_min': 22.75,
#    'temp_max': 22.75,
#    'pressure': 1021,
#    'humidity': 80,
#    'sea_level': 1021,
#    'grnd_level': 1018},
#   'visibility': 10000,
#   'wind': {'speed': 6.09, 'deg': 83},
#   'clouds': {'all': 0},
#   'dt': 1602425954,
#   'sys': {'country': 'PF', 'sunrise': 1602426601, 'sunset': 1602471751},
#   'timezone': -32400,
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'coord': {'lon': 168.86, 'lat': -46.19},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 11.67,
#    'feels_like': 8.08,
#    'temp_min': 11.67,
#    'temp_max': 11.67,
#    'pressure': 1014,
#    'humidity': 92},
#   'visibility': 10000,
#   'wind': {'speed': 5.36, 'deg': 235, 'gust': 8.49},
#   'rain': {'1h': 0.12},
#   'clouds': {'all': 69},
#   'dt': 1602425961,
#   'sys': {'type': 3,
#    'id': 2008959,
#    'country': 'NZ',
#    'sunrise': 1602438896,
#    'sunset': 1602486413},
#   'timezone': 46800,
#   'id': 6201424,
#   'name': 'Mataura',
#   'cod': 200},
#  {'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 22.75,
#    'feels_like': 21.77,
#    'temp_min': 22.75,
#    'temp_max': 22.75,
#    'pressure': 1021,
#    'humidity': 80,
#    'sea_level': 1021,
#    'grnd_level': 1018},
#   'visibility': 10000,
#   'wind': {'speed': 6.09, 'deg': 83},
#   'clouds': {'all': 0},
#   'dt': 1602425954,
#   'sys': {'country': 'PF', 'sunrise': 1602426601, 'sunset': 1602471751},
#   'timezone': -32400,
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'coord': {'lon': 57.7, 'lat': -20.41},
#   'weather': [{'id': 521,
#     'main': 'Rain',
#     'description': 'shower rain',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 24,
#    'feels_like': 26.12,
#    'temp_min': 24,
#    'temp_max': 24,
#    'pressure': 1017,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 120},
#   'clouds': {'all': 40},
#   'dt': 1602425696,
#   'sys': {'type': 1,
#    'id': 2061,
#    'country': 'MU',
#    'sunrise': 1602380489,
#    'sunset': 1602425398},
#   'timezone': 14400,
#   'id': 934322,
#   'name': 'Mahébourg',
#   'cod': 200},
#  {'coord': {'lon': 172.79, 'lat': 3.07},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 27.32,
#    'feels_like': 28.21,
#    'temp_min': 27.32,
#    'temp_max': 27.32,
#    'pressure': 1007,
#    'humidity': 75,
#    'sea_level': 1007,
#    'grnd_level': 1006},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 120},
#   'clouds': {'all': 4},
#   'dt': 1602425962,
#   'sys': {'country': 'KI', 'sunrise': 1602440006, 'sunset': 1602483417},
#   'timezone': 43200,
#   'id': 2110227,
#   'name': 'Butaritari',
#   'cod': 200},
#  {'coord': {'lon': -70.92, 'lat': -53.15},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 10.29,
#    'feels_like': -0.37,
#    'temp_min': 10,
#    'temp_max': 10.56,
#    'pressure': 996,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 13.4, 'deg': 290, 'gust': 18.5},
#   'clouds': {'all': 58},
#   'dt': 1602425962,
#   'sys': {'type': 1,
#    'id': 8487,
#    'country': 'CL',
#    'sunrise': 1602409516,
#    'sunset': 1602458098},
#   'timezone': -10800,
#   'id': 3874787,
#   'name': 'Punta Arenas',
#   'cod': 200},
#  {'coord': {'lon': -159.32, 'lat': 22.08},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 23.04,
#    'feels_like': 25.26,
#    'temp_min': 22.22,
#    'temp_max': 25,
#    'pressure': 1017,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 280},
#   'clouds': {'all': 75},
#   'dt': 1602425951,
#   'sys': {'type': 1,
#    'id': 7873,
#    'country': 'US',
#    'sunrise': 1602433923,
#    'sunset': 1602476116},
#   'timezone': -36000,
#   'id': 5848280,
#   'name': 'Kapaa',
#   'cod': 200}]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
pprint(json_data[0]['dt'])
# Out:
# 1602425948

# %%
# df = pd.DataFrame({
#     'City':[city['name'] for city in json_data[0]]
# })
city_name = latitude = longitude = max_temp = humidity= cloudiness= wind_speed = country = date =  []

# for enum,data in enumerate(json_data,start=1):
    
    
        
#         city_name.append(data['name'])
#         latitude.append(data['coord']['lat'])
#         longitude.append(data['coord']['lon'])
#         max_temp.append(data['main']['temp_max'])
#         humidity.append(data['main']['humidity'])
#         cloudiness.append(data['clouds']['all'])
#         wind_speed.append(data['wind']['speed'])
#         country.append(data['sys']['country'])
#         date.append(data[['dt']])
#     except:
#         pass
for enum,data in enumerate(json_data,start=1):   
    try:
        df1 = pd.DataFrame({
          'City':data['name'],
#           'Lat':latitude,
#           'Lng':longitude,
#           'Max Temp':max_temp,
#           'Humidity':humidity,
#           'Cloudiness':cloudiness,
#           'Wind Speed':wind_speed,
#           'Country':country,
#           'Date':date
    })
    except:
        pass
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-514ae3436c2e> in <module>
#      34     except:
#      35         pass
# ---> 36 df1
#
# NameError: name 'df1' is not defined

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
